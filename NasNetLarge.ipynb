# %%
#NASNetLarge
import warnings
from sklearn.exceptions import UndefinedMetricWarning
# Suppress specific sklearn warning
warnings.filterwarnings("ignore", category=UndefinedMetricWarning)
import os
import time
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import NASNetLarge
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from sklearn.metrics import roc_curve, auc, confusion_matrix, classification_report
# Dataset and Parameters
dataset_dir ="./Tomato"
img_size = (331, 331)
batch_size = 96
num_classes = 10
# Data Generators
datagen = ImageDataGenerator(rescale=1.0 / 255, validation_split=0.2)
train_generator = datagen.flow_from_directory(
    dataset_dir, target_size=img_size, batch_size=batch_size, class_mode="categorical", subset="training", shuffle=True)
val_generator = datagen.flow_from_directory(
    dataset_dir, target_size=img_size, batch_size=batch_size, class_mode="categorical", subset="validation", shuffle=False)

# Load ResNet50 model without the top layer
base_model = NASNetLarge(include_top=False, weights="imagenet", input_shape=(331, 331, 3))
base_model.trainable = False
for layer in base_model.layers[-5:]:
    layer.trainable = True

# Print ResNet50 layers
for idx, layer in enumerate(base_model.layers):
    print(f"Index: {idx}, Layer Name: {layer.name}, Layer Type: {layer.__class__.__name__}")

# Add custom classification head
flattened = Flatten()(base_model.output)
output = Dense(num_classes, activation="softmax")(flattened)
model = Model(inputs=base_model.input, outputs=output)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss="categorical_crossentropy", metrics=["accuracy"])

# Callbacks
reduce_lr = ReduceLROnPlateau(monitor="val_accuracy", factor=0.5, patience=10, verbose=1)
early_stop = EarlyStopping(monitor="val_accuracy", patience=10, restore_best_weights=True, verbose=1)
model_checkpoint = ModelCheckpoint("./NASNetLarge.h5", monitor="val_accuracy", save_best_only=True, verbose=1)
callbacks = [reduce_lr, early_stop, model_checkpoint]

# Training
start_time = time.time()
history = model.fit(train_generator, validation_data=val_generator, epochs=200, callbacks=callbacks)
model.save("./NASNetLarge.h5")
print(f"Training Time: {(time.time() - start_time) / 60:.2f} minutes")

# ROC Curve
y_pred = model.predict(val_generator, verbose=1)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = val_generator.classes
class_names = list(val_generator.class_indices.keys())
y_true_one_hot = to_categorical(y_true, num_classes=len(class_names))

fpr = {}
tpr_stage1 = {}
roc_auc = {}

plt.figure(figsize=(12, 8))
for i in range(len(class_names)):
    fpr[i], tpr_stage1[i], _ = roc_curve(y_true_one_hot[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr_stage1[i])
    plt.plot(fpr[i], tpr_stage1[i], label=f' {class_names[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# Plot Training History
def plot_history(history):
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(history.history["accuracy"], label="Training Accuracy")
    plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
    plt.title("Accuracy")
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(history.history["loss"], label="Training Loss")
    plt.plot(history.history["val_loss"], label="Validation Loss")
    plt.title("Loss")
    plt.legend()
    plt.show()

plot_history(history)

# Evaluate the Final Model
val_loss, val_acc = model.evaluate(val_generator)
print(f"Final Validation Accuracy: {val_acc:.4f}")
print(f"Final Validation Loss: {val_loss:.4f}")

# Confusion Matrix and Report
y_pred = model.predict(val_generator, batch_size=batch_size, verbose=1)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = val_generator.classes

conf_matrix = confusion_matrix(y_true, y_pred_classes)
print("Confusion Matrix:")
print(conf_matrix)

print("Classification Report:")
print(classification_report(y_true, y_pred_classes))

# Plot Confusion Matrix
def plot_confusion_matrix(cm, classes):
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=classes, yticklabels=classes)
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.title("Confusion Matrix")
    plt.show()

class_labels = list(val_generator.class_indices.keys())
plot_confusion_matrix(conf_matrix, class_labels)
# Out:
# Found 32000 images belonging to 10 classes.
# Found 8000 images belonging to 10 classes.
# Index: 0, Layer Name: input_1, Layer Type: InputLayer
# Index: 1, Layer Name: stem_conv1, Layer Type: Conv2D
# Index: 2, Layer Name: stem_bn1, Layer Type: BatchNormalization
# Index: 3, Layer Name: activation, Layer Type: Activation
# Index: 4, Layer Name: reduction_conv_1_stem_1, Layer Type: Conv2D
# Index: 5, Layer Name: reduction_bn_1_stem_1, Layer Type: BatchNormalization
# Index: 6, Layer Name: activation_1, Layer Type: Activation
# Index: 7, Layer Name: activation_3, Layer Type: Activation
# Index: 8, Layer Name: separable_conv_1_pad_reduction_left1_stem_1, Layer Type: ZeroPadding2D
# Index: 9, Layer Name: separable_conv_1_pad_reduction_right1_stem_1, Layer Type: ZeroPadding2D
# Index: 10, Layer Name: separable_conv_1_reduction_left1_stem_1, Layer Type: SeparableConv2D
# Index: 11, Layer Name: separable_conv_1_reduction_right1_stem_1, Layer Type: SeparableConv2D
# Index: 12, Layer Name: separable_conv_1_bn_reduction_left1_stem_1, Layer Type: BatchNormalization
# Index: 13, Layer Name: separable_conv_1_bn_reduction_right1_stem_1, Layer Type: BatchNormalization
# Index: 14, Layer Name: activation_2, Layer Type: Activation
# Index: 15, Layer Name: activation_4, Layer Type: Activation
# Index: 16, Layer Name: separable_conv_2_reduction_left1_stem_1, Layer Type: SeparableConv2D
# Index: 17, Layer Name: separable_conv_2_reduction_right1_stem_1, Layer Type: SeparableConv2D
# Index: 18, Layer Name: activation_5, Layer Type: Activation
# Index: 19, Layer Name: separable_conv_2_bn_reduction_left1_stem_1, Layer Type: BatchNormalization
# Index: 20, Layer Name: separable_conv_2_bn_reduction_right1_stem_1, Layer Type: BatchNormalization
# Index: 21, Layer Name: separable_conv_1_pad_reduction_right2_stem_1, Layer Type: ZeroPadding2D
# Index: 22, Layer Name: activation_7, Layer Type: Activation
# Index: 23, Layer Name: reduction_add_1_stem_1, Layer Type: Add
# Index: 24, Layer Name: separable_conv_1_reduction_right2_stem_1, Layer Type: SeparableConv2D
# Index: 25, Layer Name: separable_conv_1_pad_reduction_right3_stem_1, Layer Type: ZeroPadding2D
# Index: 26, Layer Name: activation_9, Layer Type: Activation
# Index: 27, Layer Name: separable_conv_1_bn_reduction_right2_stem_1, Layer Type: BatchNormalization
# Index: 28, Layer Name: separable_conv_1_reduction_right3_stem_1, Layer Type: SeparableConv2D
# Index: 29, Layer Name: separable_conv_1_reduction_left4_stem_1, Layer Type: SeparableConv2D
# Index: 30, Layer Name: activation_6, Layer Type: Activation
# Index: 31, Layer Name: separable_conv_1_bn_reduction_right3_stem_1, Layer Type: BatchNormalization
# Index: 32, Layer Name: separable_conv_1_bn_reduction_left4_stem_1, Layer Type: BatchNormalization
# Index: 33, Layer Name: reduction_pad_1_stem_1, Layer Type: ZeroPadding2D
# Index: 34, Layer Name: separable_conv_2_reduction_right2_stem_1, Layer Type: SeparableConv2D
# Index: 35, Layer Name: activation_8, Layer Type: Activation
# Index: 36, Layer Name: activation_10, Layer Type: Activation
# Index: 37, Layer Name: reduction_left2_stem_1, Layer Type: MaxPooling2D
# Index: 38, Layer Name: separable_conv_2_bn_reduction_right2_stem_1, Layer Type: BatchNormalization
# Index: 39, Layer Name: separable_conv_2_reduction_right3_stem_1, Layer Type: SeparableConv2D
# Index: 40, Layer Name: separable_conv_2_reduction_left4_stem_1, Layer Type: SeparableConv2D
# Index: 41, Layer Name: adjust_relu_1_stem_2, Layer Type: Activation
# Index: 42, Layer Name: reduction_add_2_stem_1, Layer Type: Add
# Index: 43, Layer Name: reduction_left3_stem_1, Layer Type: AveragePooling2D
# Index: 44, Layer Name: separable_conv_2_bn_reduction_right3_stem_1, Layer Type: BatchNormalization
# Index: 45, Layer Name: reduction_left4_stem_1, Layer Type: AveragePooling2D
# Index: 46, Layer Name: separable_conv_2_bn_reduction_left4_stem_1, Layer Type: BatchNormalization
# Index: 47, Layer Name: reduction_right5_stem_1, Layer Type: MaxPooling2D
# Index: 48, Layer Name: zero_padding2d, Layer Type: ZeroPadding2D
# Index: 49, Layer Name: reduction_add3_stem_1, Layer Type: Add
# Index: 50, Layer Name: add, Layer Type: Add
# Index: 51, Layer Name: reduction_add4_stem_1, Layer Type: Add
# Index: 52, Layer Name: cropping2d, Layer Type: Cropping2D
# Index: 53, Layer Name: reduction_concat_stem_1, Layer Type: Concatenate
# Index: 54, Layer Name: adjust_avg_pool_1_stem_2, Layer Type: AveragePooling2D
# Index: 55, Layer Name: adjust_avg_pool_2_stem_2, Layer Type: AveragePooling2D
# Index: 56, Layer Name: activation_11, Layer Type: Activation
# Index: 57, Layer Name: adjust_conv_1_stem_2, Layer Type: Conv2D
# Index: 58, Layer Name: adjust_conv_2_stem_2, Layer Type: Conv2D
# Index: 59, Layer Name: reduction_conv_1_stem_2, Layer Type: Conv2D
# Index: 60, Layer Name: concatenate, Layer Type: Concatenate
# Index: 61, Layer Name: reduction_bn_1_stem_2, Layer Type: BatchNormalization
# Index: 62, Layer Name: adjust_bn_stem_2, Layer Type: BatchNormalization
# Index: 63, Layer Name: activation_12, Layer Type: Activation
# Index: 64, Layer Name: activation_14, Layer Type: Activation
# Index: 65, Layer Name: separable_conv_1_pad_reduction_left1_stem_2, Layer Type: ZeroPadding2D
# Index: 66, Layer Name: separable_conv_1_pad_reduction_right1_stem_2, Layer Type: ZeroPadding2D
# Index: 67, Layer Name: separable_conv_1_reduction_left1_stem_2, Layer Type: SeparableConv2D
# Index: 68, Layer Name: separable_conv_1_reduction_right1_stem_2, Layer Type: SeparableConv2D
# Index: 69, Layer Name: separable_conv_1_bn_reduction_left1_stem_2, Layer Type: BatchNormalization
# Index: 70, Layer Name: separable_conv_1_bn_reduction_right1_stem_2, Layer Type: BatchNormalization
# Index: 71, Layer Name: activation_13, Layer Type: Activation
# Index: 72, Layer Name: activation_15, Layer Type: Activation
# Index: 73, Layer Name: separable_conv_2_reduction_left1_stem_2, Layer Type: SeparableConv2D
# Index: 74, Layer Name: separable_conv_2_reduction_right1_stem_2, Layer Type: SeparableConv2D
# Index: 75, Layer Name: activation_16, Layer Type: Activation
# Index: 76, Layer Name: separable_conv_2_bn_reduction_left1_stem_2, Layer Type: BatchNormalization
# Index: 77, Layer Name: separable_conv_2_bn_reduction_right1_stem_2, Layer Type: BatchNormalization
# Index: 78, Layer Name: separable_conv_1_pad_reduction_right2_stem_2, Layer Type: ZeroPadding2D
# Index: 79, Layer Name: activation_18, Layer Type: Activation
# Index: 80, Layer Name: reduction_add_1_stem_2, Layer Type: Add
# Index: 81, Layer Name: separable_conv_1_reduction_right2_stem_2, Layer Type: SeparableConv2D
# Index: 82, Layer Name: separable_conv_1_pad_reduction_right3_stem_2, Layer Type: ZeroPadding2D
# Index: 83, Layer Name: activation_20, Layer Type: Activation
# Index: 84, Layer Name: separable_conv_1_bn_reduction_right2_stem_2, Layer Type: BatchNormalization
# Index: 85, Layer Name: separable_conv_1_reduction_right3_stem_2, Layer Type: SeparableConv2D
# Index: 86, Layer Name: separable_conv_1_reduction_left4_stem_2, Layer Type: SeparableConv2D
# Index: 87, Layer Name: activation_17, Layer Type: Activation
# Index: 88, Layer Name: separable_conv_1_bn_reduction_right3_stem_2, Layer Type: BatchNormalization
# Index: 89, Layer Name: separable_conv_1_bn_reduction_left4_stem_2, Layer Type: BatchNormalization
# Index: 90, Layer Name: reduction_pad_1_stem_2, Layer Type: ZeroPadding2D
# Index: 91, Layer Name: separable_conv_2_reduction_right2_stem_2, Layer Type: SeparableConv2D
# Index: 92, Layer Name: activation_19, Layer Type: Activation
# Index: 93, Layer Name: activation_21, Layer Type: Activation
# Index: 94, Layer Name: reduction_left2_stem_2, Layer Type: MaxPooling2D
# Index: 95, Layer Name: separable_conv_2_bn_reduction_right2_stem_2, Layer Type: BatchNormalization
# Index: 96, Layer Name: separable_conv_2_reduction_right3_stem_2, Layer Type: SeparableConv2D
# Index: 97, Layer Name: separable_conv_2_reduction_left4_stem_2, Layer Type: SeparableConv2D
# Index: 98, Layer Name: adjust_relu_1_0, Layer Type: Activation
# Index: 99, Layer Name: reduction_add_2_stem_2, Layer Type: Add
# Index: 100, Layer Name: reduction_left3_stem_2, Layer Type: AveragePooling2D
# Index: 101, Layer Name: separable_conv_2_bn_reduction_right3_stem_2, Layer Type: BatchNormalization
# Index: 102, Layer Name: reduction_left4_stem_2, Layer Type: AveragePooling2D
# Index: 103, Layer Name: separable_conv_2_bn_reduction_left4_stem_2, Layer Type: BatchNormalization
# Index: 104, Layer Name: reduction_right5_stem_2, Layer Type: MaxPooling2D
# Index: 105, Layer Name: zero_padding2d_1, Layer Type: ZeroPadding2D
# Index: 106, Layer Name: reduction_add3_stem_2, Layer Type: Add
# Index: 107, Layer Name: add_1, Layer Type: Add
# Index: 108, Layer Name: reduction_add4_stem_2, Layer Type: Add
# Index: 109, Layer Name: cropping2d_1, Layer Type: Cropping2D
# Index: 110, Layer Name: reduction_concat_stem_2, Layer Type: Concatenate
# Index: 111, Layer Name: adjust_avg_pool_1_0, Layer Type: AveragePooling2D
# Index: 112, Layer Name: adjust_avg_pool_2_0, Layer Type: AveragePooling2D
# Index: 113, Layer Name: adjust_conv_1_0, Layer Type: Conv2D
# Index: 114, Layer Name: adjust_conv_2_0, Layer Type: Conv2D
# Index: 115, Layer Name: activation_22, Layer Type: Activation
# Index: 116, Layer Name: concatenate_1, Layer Type: Concatenate
# Index: 117, Layer Name: normal_conv_1_0, Layer Type: Conv2D
# Index: 118, Layer Name: adjust_bn_0, Layer Type: BatchNormalization
# Index: 119, Layer Name: normal_bn_1_0, Layer Type: BatchNormalization
# Index: 120, Layer Name: activation_23, Layer Type: Activation
# Index: 121, Layer Name: activation_25, Layer Type: Activation
# Index: 122, Layer Name: activation_27, Layer Type: Activation
# Index: 123, Layer Name: activation_29, Layer Type: Activation
# Index: 124, Layer Name: activation_31, Layer Type: Activation
# Index: 125, Layer Name: separable_conv_1_normal_left1_0, Layer Type: SeparableConv2D
# Index: 126, Layer Name: separable_conv_1_normal_right1_0, Layer Type: SeparableConv2D
# Index: 127, Layer Name: separable_conv_1_normal_left2_0, Layer Type: SeparableConv2D
# Index: 128, Layer Name: separable_conv_1_normal_right2_0, Layer Type: SeparableConv2D
# Index: 129, Layer Name: separable_conv_1_normal_left5_0, Layer Type: SeparableConv2D
# Index: 130, Layer Name: separable_conv_1_bn_normal_left1_0, Layer Type: BatchNormalization
# Index: 131, Layer Name: separable_conv_1_bn_normal_right1_0, Layer Type: BatchNormalization
# Index: 132, Layer Name: separable_conv_1_bn_normal_left2_0, Layer Type: BatchNormalization
# Index: 133, Layer Name: separable_conv_1_bn_normal_right2_0, Layer Type: BatchNormalization
# Index: 134, Layer Name: separable_conv_1_bn_normal_left5_0, Layer Type: BatchNormalization
# Index: 135, Layer Name: activation_24, Layer Type: Activation
# Index: 136, Layer Name: activation_26, Layer Type: Activation
# Index: 137, Layer Name: activation_28, Layer Type: Activation
# Index: 138, Layer Name: activation_30, Layer Type: Activation
# Index: 139, Layer Name: activation_32, Layer Type: Activation
# Index: 140, Layer Name: separable_conv_2_normal_left1_0, Layer Type: SeparableConv2D
# Index: 141, Layer Name: separable_conv_2_normal_right1_0, Layer Type: SeparableConv2D
# Index: 142, Layer Name: separable_conv_2_normal_left2_0, Layer Type: SeparableConv2D
# Index: 143, Layer Name: separable_conv_2_normal_right2_0, Layer Type: SeparableConv2D
# Index: 144, Layer Name: separable_conv_2_normal_left5_0, Layer Type: SeparableConv2D
# Index: 145, Layer Name: separable_conv_2_bn_normal_left1_0, Layer Type: BatchNormalization
# Index: 146, Layer Name: separable_conv_2_bn_normal_right1_0, Layer Type: BatchNormalization
# Index: 147, Layer Name: separable_conv_2_bn_normal_left2_0, Layer Type: BatchNormalization
# Index: 148, Layer Name: separable_conv_2_bn_normal_right2_0, Layer Type: BatchNormalization
# Index: 149, Layer Name: normal_left3_0, Layer Type: AveragePooling2D
# Index: 150, Layer Name: normal_left4_0, Layer Type: AveragePooling2D
# Index: 151, Layer Name: normal_right4_0, Layer Type: AveragePooling2D
# Index: 152, Layer Name: separable_conv_2_bn_normal_left5_0, Layer Type: BatchNormalization
# Index: 153, Layer Name: normal_add_1_0, Layer Type: Add
# Index: 154, Layer Name: normal_add_2_0, Layer Type: Add
# Index: 155, Layer Name: normal_add_3_0, Layer Type: Add
# Index: 156, Layer Name: normal_add_4_0, Layer Type: Add
# Index: 157, Layer Name: normal_add_5_0, Layer Type: Add
# Index: 158, Layer Name: normal_concat_0, Layer Type: Concatenate
# Index: 159, Layer Name: activation_33, Layer Type: Activation
# Index: 160, Layer Name: activation_34, Layer Type: Activation
# Index: 161, Layer Name: adjust_conv_projection_1, Layer Type: Conv2D
# Index: 162, Layer Name: normal_conv_1_1, Layer Type: Conv2D
# Index: 163, Layer Name: adjust_bn_1, Layer Type: BatchNormalization
# Index: 164, Layer Name: normal_bn_1_1, Layer Type: BatchNormalization
# Index: 165, Layer Name: activation_35, Layer Type: Activation
# Index: 166, Layer Name: activation_37, Layer Type: Activation
# Index: 167, Layer Name: activation_39, Layer Type: Activation
# Index: 168, Layer Name: activation_41, Layer Type: Activation
# Index: 169, Layer Name: activation_43, Layer Type: Activation
# Index: 170, Layer Name: separable_conv_1_normal_left1_1, Layer Type: SeparableConv2D
# Index: 171, Layer Name: separable_conv_1_normal_right1_1, Layer Type: SeparableConv2D
# Index: 172, Layer Name: separable_conv_1_normal_left2_1, Layer Type: SeparableConv2D
# Index: 173, Layer Name: separable_conv_1_normal_right2_1, Layer Type: SeparableConv2D
# Index: 174, Layer Name: separable_conv_1_normal_left5_1, Layer Type: SeparableConv2D
# Index: 175, Layer Name: separable_conv_1_bn_normal_left1_1, Layer Type: BatchNormalization
# Index: 176, Layer Name: separable_conv_1_bn_normal_right1_1, Layer Type: BatchNormalization
# Index: 177, Layer Name: separable_conv_1_bn_normal_left2_1, Layer Type: BatchNormalization
# Index: 178, Layer Name: separable_conv_1_bn_normal_right2_1, Layer Type: BatchNormalization
# Index: 179, Layer Name: separable_conv_1_bn_normal_left5_1, Layer Type: BatchNormalization
# Index: 180, Layer Name: activation_36, Layer Type: Activation
# Index: 181, Layer Name: activation_38, Layer Type: Activation
# Index: 182, Layer Name: activation_40, Layer Type: Activation
# Index: 183, Layer Name: activation_42, Layer Type: Activation
# Index: 184, Layer Name: activation_44, Layer Type: Activation
# Index: 185, Layer Name: separable_conv_2_normal_left1_1, Layer Type: SeparableConv2D
# Index: 186, Layer Name: separable_conv_2_normal_right1_1, Layer Type: SeparableConv2D
# Index: 187, Layer Name: separable_conv_2_normal_left2_1, Layer Type: SeparableConv2D
# Index: 188, Layer Name: separable_conv_2_normal_right2_1, Layer Type: SeparableConv2D
# Index: 189, Layer Name: separable_conv_2_normal_left5_1, Layer Type: SeparableConv2D
# Index: 190, Layer Name: separable_conv_2_bn_normal_left1_1, Layer Type: BatchNormalization
# Index: 191, Layer Name: separable_conv_2_bn_normal_right1_1, Layer Type: BatchNormalization
# Index: 192, Layer Name: separable_conv_2_bn_normal_left2_1, Layer Type: BatchNormalization
# Index: 193, Layer Name: separable_conv_2_bn_normal_right2_1, Layer Type: BatchNormalization
# Index: 194, Layer Name: normal_left3_1, Layer Type: AveragePooling2D
# Index: 195, Layer Name: normal_left4_1, Layer Type: AveragePooling2D
# Index: 196, Layer Name: normal_right4_1, Layer Type: AveragePooling2D
# Index: 197, Layer Name: separable_conv_2_bn_normal_left5_1, Layer Type: BatchNormalization
# Index: 198, Layer Name: normal_add_1_1, Layer Type: Add
# Index: 199, Layer Name: normal_add_2_1, Layer Type: Add
# Index: 200, Layer Name: normal_add_3_1, Layer Type: Add
# Index: 201, Layer Name: normal_add_4_1, Layer Type: Add
# Index: 202, Layer Name: normal_add_5_1, Layer Type: Add
# Index: 203, Layer Name: normal_concat_1, Layer Type: Concatenate
# Index: 204, Layer Name: activation_45, Layer Type: Activation
# Index: 205, Layer Name: activation_46, Layer Type: Activation
# Index: 206, Layer Name: adjust_conv_projection_2, Layer Type: Conv2D
# Index: 207, Layer Name: normal_conv_1_2, Layer Type: Conv2D
# Index: 208, Layer Name: adjust_bn_2, Layer Type: BatchNormalization
# Index: 209, Layer Name: normal_bn_1_2, Layer Type: BatchNormalization
# Index: 210, Layer Name: activation_47, Layer Type: Activation
# Index: 211, Layer Name: activation_49, Layer Type: Activation
# Index: 212, Layer Name: activation_51, Layer Type: Activation
# Index: 213, Layer Name: activation_53, Layer Type: Activation
# Index: 214, Layer Name: activation_55, Layer Type: Activation
# Index: 215, Layer Name: separable_conv_1_normal_left1_2, Layer Type: SeparableConv2D
# Index: 216, Layer Name: separable_conv_1_normal_right1_2, Layer Type: SeparableConv2D
# Index: 217, Layer Name: separable_conv_1_normal_left2_2, Layer Type: SeparableConv2D
# Index: 218, Layer Name: separable_conv_1_normal_right2_2, Layer Type: SeparableConv2D
# Index: 219, Layer Name: separable_conv_1_normal_left5_2, Layer Type: SeparableConv2D
# Index: 220, Layer Name: separable_conv_1_bn_normal_left1_2, Layer Type: BatchNormalization
# Index: 221, Layer Name: separable_conv_1_bn_normal_right1_2, Layer Type: BatchNormalization
# Index: 222, Layer Name: separable_conv_1_bn_normal_left2_2, Layer Type: BatchNormalization
# Index: 223, Layer Name: separable_conv_1_bn_normal_right2_2, Layer Type: BatchNormalization
# Index: 224, Layer Name: separable_conv_1_bn_normal_left5_2, Layer Type: BatchNormalization
# Index: 225, Layer Name: activation_48, Layer Type: Activation
# Index: 226, Layer Name: activation_50, Layer Type: Activation
# Index: 227, Layer Name: activation_52, Layer Type: Activation
# Index: 228, Layer Name: activation_54, Layer Type: Activation
# Index: 229, Layer Name: activation_56, Layer Type: Activation
# Index: 230, Layer Name: separable_conv_2_normal_left1_2, Layer Type: SeparableConv2D
# Index: 231, Layer Name: separable_conv_2_normal_right1_2, Layer Type: SeparableConv2D
# Index: 232, Layer Name: separable_conv_2_normal_left2_2, Layer Type: SeparableConv2D
# Index: 233, Layer Name: separable_conv_2_normal_right2_2, Layer Type: SeparableConv2D
# Index: 234, Layer Name: separable_conv_2_normal_left5_2, Layer Type: SeparableConv2D
# Index: 235, Layer Name: separable_conv_2_bn_normal_left1_2, Layer Type: BatchNormalization
# Index: 236, Layer Name: separable_conv_2_bn_normal_right1_2, Layer Type: BatchNormalization
# Index: 237, Layer Name: separable_conv_2_bn_normal_left2_2, Layer Type: BatchNormalization
# Index: 238, Layer Name: separable_conv_2_bn_normal_right2_2, Layer Type: BatchNormalization
# Index: 239, Layer Name: normal_left3_2, Layer Type: AveragePooling2D
# Index: 240, Layer Name: normal_left4_2, Layer Type: AveragePooling2D
# Index: 241, Layer Name: normal_right4_2, Layer Type: AveragePooling2D
# Index: 242, Layer Name: separable_conv_2_bn_normal_left5_2, Layer Type: BatchNormalization
# Index: 243, Layer Name: normal_add_1_2, Layer Type: Add
# Index: 244, Layer Name: normal_add_2_2, Layer Type: Add
# Index: 245, Layer Name: normal_add_3_2, Layer Type: Add
# Index: 246, Layer Name: normal_add_4_2, Layer Type: Add
# Index: 247, Layer Name: normal_add_5_2, Layer Type: Add
# Index: 248, Layer Name: normal_concat_2, Layer Type: Concatenate
# Index: 249, Layer Name: activation_57, Layer Type: Activation
# Index: 250, Layer Name: activation_58, Layer Type: Activation
# Index: 251, Layer Name: adjust_conv_projection_3, Layer Type: Conv2D
# Index: 252, Layer Name: normal_conv_1_3, Layer Type: Conv2D
# Index: 253, Layer Name: adjust_bn_3, Layer Type: BatchNormalization
# Index: 254, Layer Name: normal_bn_1_3, Layer Type: BatchNormalization
# Index: 255, Layer Name: activation_59, Layer Type: Activation
# Index: 256, Layer Name: activation_61, Layer Type: Activation
# Index: 257, Layer Name: activation_63, Layer Type: Activation
# Index: 258, Layer Name: activation_65, Layer Type: Activation
# Index: 259, Layer Name: activation_67, Layer Type: Activation
# Index: 260, Layer Name: separable_conv_1_normal_left1_3, Layer Type: SeparableConv2D
# Index: 261, Layer Name: separable_conv_1_normal_right1_3, Layer Type: SeparableConv2D
# Index: 262, Layer Name: separable_conv_1_normal_left2_3, Layer Type: SeparableConv2D
# Index: 263, Layer Name: separable_conv_1_normal_right2_3, Layer Type: SeparableConv2D
# Index: 264, Layer Name: separable_conv_1_normal_left5_3, Layer Type: SeparableConv2D
# Index: 265, Layer Name: separable_conv_1_bn_normal_left1_3, Layer Type: BatchNormalization
# Index: 266, Layer Name: separable_conv_1_bn_normal_right1_3, Layer Type: BatchNormalization
# Index: 267, Layer Name: separable_conv_1_bn_normal_left2_3, Layer Type: BatchNormalization
# Index: 268, Layer Name: separable_conv_1_bn_normal_right2_3, Layer Type: BatchNormalization
# Index: 269, Layer Name: separable_conv_1_bn_normal_left5_3, Layer Type: BatchNormalization
# Index: 270, Layer Name: activation_60, Layer Type: Activation
# Index: 271, Layer Name: activation_62, Layer Type: Activation
# Index: 272, Layer Name: activation_64, Layer Type: Activation
# Index: 273, Layer Name: activation_66, Layer Type: Activation
# Index: 274, Layer Name: activation_68, Layer Type: Activation
# Index: 275, Layer Name: separable_conv_2_normal_left1_3, Layer Type: SeparableConv2D
# Index: 276, Layer Name: separable_conv_2_normal_right1_3, Layer Type: SeparableConv2D
# Index: 277, Layer Name: separable_conv_2_normal_left2_3, Layer Type: SeparableConv2D
# Index: 278, Layer Name: separable_conv_2_normal_right2_3, Layer Type: SeparableConv2D
# Index: 279, Layer Name: separable_conv_2_normal_left5_3, Layer Type: SeparableConv2D
# Index: 280, Layer Name: separable_conv_2_bn_normal_left1_3, Layer Type: BatchNormalization
# Index: 281, Layer Name: separable_conv_2_bn_normal_right1_3, Layer Type: BatchNormalization
# Index: 282, Layer Name: separable_conv_2_bn_normal_left2_3, Layer Type: BatchNormalization
# Index: 283, Layer Name: separable_conv_2_bn_normal_right2_3, Layer Type: BatchNormalization
# Index: 284, Layer Name: normal_left3_3, Layer Type: AveragePooling2D
# Index: 285, Layer Name: normal_left4_3, Layer Type: AveragePooling2D
# Index: 286, Layer Name: normal_right4_3, Layer Type: AveragePooling2D
# Index: 287, Layer Name: separable_conv_2_bn_normal_left5_3, Layer Type: BatchNormalization
# Index: 288, Layer Name: normal_add_1_3, Layer Type: Add
# Index: 289, Layer Name: normal_add_2_3, Layer Type: Add
# Index: 290, Layer Name: normal_add_3_3, Layer Type: Add
# Index: 291, Layer Name: normal_add_4_3, Layer Type: Add
# Index: 292, Layer Name: normal_add_5_3, Layer Type: Add
# Index: 293, Layer Name: normal_concat_3, Layer Type: Concatenate
# Index: 294, Layer Name: activation_69, Layer Type: Activation
# Index: 295, Layer Name: activation_70, Layer Type: Activation
# Index: 296, Layer Name: adjust_conv_projection_4, Layer Type: Conv2D
# Index: 297, Layer Name: normal_conv_1_4, Layer Type: Conv2D
# Index: 298, Layer Name: adjust_bn_4, Layer Type: BatchNormalization
# Index: 299, Layer Name: normal_bn_1_4, Layer Type: BatchNormalization
# Index: 300, Layer Name: activation_71, Layer Type: Activation
# Index: 301, Layer Name: activation_73, Layer Type: Activation
# Index: 302, Layer Name: activation_75, Layer Type: Activation
# Index: 303, Layer Name: activation_77, Layer Type: Activation
# Index: 304, Layer Name: activation_79, Layer Type: Activation
# Index: 305, Layer Name: separable_conv_1_normal_left1_4, Layer Type: SeparableConv2D
# Index: 306, Layer Name: separable_conv_1_normal_right1_4, Layer Type: SeparableConv2D
# Index: 307, Layer Name: separable_conv_1_normal_left2_4, Layer Type: SeparableConv2D
# Index: 308, Layer Name: separable_conv_1_normal_right2_4, Layer Type: SeparableConv2D
# Index: 309, Layer Name: separable_conv_1_normal_left5_4, Layer Type: SeparableConv2D
# Index: 310, Layer Name: separable_conv_1_bn_normal_left1_4, Layer Type: BatchNormalization
# Index: 311, Layer Name: separable_conv_1_bn_normal_right1_4, Layer Type: BatchNormalization
# Index: 312, Layer Name: separable_conv_1_bn_normal_left2_4, Layer Type: BatchNormalization
# Index: 313, Layer Name: separable_conv_1_bn_normal_right2_4, Layer Type: BatchNormalization
# Index: 314, Layer Name: separable_conv_1_bn_normal_left5_4, Layer Type: BatchNormalization
# Index: 315, Layer Name: activation_72, Layer Type: Activation
# Index: 316, Layer Name: activation_74, Layer Type: Activation
# Index: 317, Layer Name: activation_76, Layer Type: Activation
# Index: 318, Layer Name: activation_78, Layer Type: Activation
# Index: 319, Layer Name: activation_80, Layer Type: Activation
# Index: 320, Layer Name: separable_conv_2_normal_left1_4, Layer Type: SeparableConv2D
# Index: 321, Layer Name: separable_conv_2_normal_right1_4, Layer Type: SeparableConv2D
# Index: 322, Layer Name: separable_conv_2_normal_left2_4, Layer Type: SeparableConv2D
# Index: 323, Layer Name: separable_conv_2_normal_right2_4, Layer Type: SeparableConv2D
# Index: 324, Layer Name: separable_conv_2_normal_left5_4, Layer Type: SeparableConv2D
# Index: 325, Layer Name: separable_conv_2_bn_normal_left1_4, Layer Type: BatchNormalization
# Index: 326, Layer Name: separable_conv_2_bn_normal_right1_4, Layer Type: BatchNormalization
# Index: 327, Layer Name: separable_conv_2_bn_normal_left2_4, Layer Type: BatchNormalization
# Index: 328, Layer Name: separable_conv_2_bn_normal_right2_4, Layer Type: BatchNormalization
# Index: 329, Layer Name: normal_left3_4, Layer Type: AveragePooling2D
# Index: 330, Layer Name: normal_left4_4, Layer Type: AveragePooling2D
# Index: 331, Layer Name: normal_right4_4, Layer Type: AveragePooling2D
# Index: 332, Layer Name: separable_conv_2_bn_normal_left5_4, Layer Type: BatchNormalization
# Index: 333, Layer Name: normal_add_1_4, Layer Type: Add
# Index: 334, Layer Name: normal_add_2_4, Layer Type: Add
# Index: 335, Layer Name: normal_add_3_4, Layer Type: Add
# Index: 336, Layer Name: normal_add_4_4, Layer Type: Add
# Index: 337, Layer Name: normal_add_5_4, Layer Type: Add
# Index: 338, Layer Name: normal_concat_4, Layer Type: Concatenate
# Index: 339, Layer Name: activation_81, Layer Type: Activation
# Index: 340, Layer Name: activation_82, Layer Type: Activation
# Index: 341, Layer Name: adjust_conv_projection_5, Layer Type: Conv2D
# Index: 342, Layer Name: normal_conv_1_5, Layer Type: Conv2D
# Index: 343, Layer Name: adjust_bn_5, Layer Type: BatchNormalization
# Index: 344, Layer Name: normal_bn_1_5, Layer Type: BatchNormalization
# Index: 345, Layer Name: activation_83, Layer Type: Activation
# Index: 346, Layer Name: activation_85, Layer Type: Activation
# Index: 347, Layer Name: activation_87, Layer Type: Activation
# Index: 348, Layer Name: activation_89, Layer Type: Activation
# Index: 349, Layer Name: activation_91, Layer Type: Activation
# Index: 350, Layer Name: separable_conv_1_normal_left1_5, Layer Type: SeparableConv2D
# Index: 351, Layer Name: separable_conv_1_normal_right1_5, Layer Type: SeparableConv2D
# Index: 352, Layer Name: separable_conv_1_normal_left2_5, Layer Type: SeparableConv2D
# Index: 353, Layer Name: separable_conv_1_normal_right2_5, Layer Type: SeparableConv2D
# Index: 354, Layer Name: separable_conv_1_normal_left5_5, Layer Type: SeparableConv2D
# Index: 355, Layer Name: separable_conv_1_bn_normal_left1_5, Layer Type: BatchNormalization
# Index: 356, Layer Name: separable_conv_1_bn_normal_right1_5, Layer Type: BatchNormalization
# Index: 357, Layer Name: separable_conv_1_bn_normal_left2_5, Layer Type: BatchNormalization
# Index: 358, Layer Name: separable_conv_1_bn_normal_right2_5, Layer Type: BatchNormalization
# Index: 359, Layer Name: separable_conv_1_bn_normal_left5_5, Layer Type: BatchNormalization
# Index: 360, Layer Name: activation_84, Layer Type: Activation
# Index: 361, Layer Name: activation_86, Layer Type: Activation
# Index: 362, Layer Name: activation_88, Layer Type: Activation
# Index: 363, Layer Name: activation_90, Layer Type: Activation
# Index: 364, Layer Name: activation_92, Layer Type: Activation
# Index: 365, Layer Name: separable_conv_2_normal_left1_5, Layer Type: SeparableConv2D
# Index: 366, Layer Name: separable_conv_2_normal_right1_5, Layer Type: SeparableConv2D
# Index: 367, Layer Name: separable_conv_2_normal_left2_5, Layer Type: SeparableConv2D
# Index: 368, Layer Name: separable_conv_2_normal_right2_5, Layer Type: SeparableConv2D
# Index: 369, Layer Name: separable_conv_2_normal_left5_5, Layer Type: SeparableConv2D
# Index: 370, Layer Name: separable_conv_2_bn_normal_left1_5, Layer Type: BatchNormalization
# Index: 371, Layer Name: separable_conv_2_bn_normal_right1_5, Layer Type: BatchNormalization
# Index: 372, Layer Name: separable_conv_2_bn_normal_left2_5, Layer Type: BatchNormalization
# Index: 373, Layer Name: separable_conv_2_bn_normal_right2_5, Layer Type: BatchNormalization
# Index: 374, Layer Name: normal_left3_5, Layer Type: AveragePooling2D
# Index: 375, Layer Name: normal_left4_5, Layer Type: AveragePooling2D
# Index: 376, Layer Name: normal_right4_5, Layer Type: AveragePooling2D
# Index: 377, Layer Name: separable_conv_2_bn_normal_left5_5, Layer Type: BatchNormalization
# Index: 378, Layer Name: normal_add_1_5, Layer Type: Add
# Index: 379, Layer Name: normal_add_2_5, Layer Type: Add
# Index: 380, Layer Name: normal_add_3_5, Layer Type: Add
# Index: 381, Layer Name: normal_add_4_5, Layer Type: Add
# Index: 382, Layer Name: normal_add_5_5, Layer Type: Add
# Index: 383, Layer Name: normal_concat_5, Layer Type: Concatenate
# Index: 384, Layer Name: activation_94, Layer Type: Activation
# Index: 385, Layer Name: activation_93, Layer Type: Activation
# Index: 386, Layer Name: reduction_conv_1_reduce_6, Layer Type: Conv2D
# Index: 387, Layer Name: adjust_conv_projection_reduce_6, Layer Type: Conv2D
# Index: 388, Layer Name: reduction_bn_1_reduce_6, Layer Type: BatchNormalization
# Index: 389, Layer Name: adjust_bn_reduce_6, Layer Type: BatchNormalization
# Index: 390, Layer Name: activation_95, Layer Type: Activation
# Index: 391, Layer Name: activation_97, Layer Type: Activation
# Index: 392, Layer Name: separable_conv_1_pad_reduction_left1_reduce_6, Layer Type: ZeroPadding2D
# Index: 393, Layer Name: separable_conv_1_pad_reduction_right1_reduce_6, Layer Type: ZeroPadding2D
# Index: 394, Layer Name: separable_conv_1_reduction_left1_reduce_6, Layer Type: SeparableConv2D
# Index: 395, Layer Name: separable_conv_1_reduction_right1_reduce_6, Layer Type: SeparableConv2D
# Index: 396, Layer Name: separable_conv_1_bn_reduction_left1_reduce_6, Layer Type: BatchNormalization
# Index: 397, Layer Name: separable_conv_1_bn_reduction_right1_reduce_6, Layer Type: BatchNormalization
# Index: 398, Layer Name: activation_96, Layer Type: Activation
# Index: 399, Layer Name: activation_98, Layer Type: Activation
# Index: 400, Layer Name: separable_conv_2_reduction_left1_reduce_6, Layer Type: SeparableConv2D
# Index: 401, Layer Name: separable_conv_2_reduction_right1_reduce_6, Layer Type: SeparableConv2D
# Index: 402, Layer Name: activation_99, Layer Type: Activation
# Index: 403, Layer Name: separable_conv_2_bn_reduction_left1_reduce_6, Layer Type: BatchNormalization
# Index: 404, Layer Name: separable_conv_2_bn_reduction_right1_reduce_6, Layer Type: BatchNormalization
# Index: 405, Layer Name: separable_conv_1_pad_reduction_right2_reduce_6, Layer Type: ZeroPadding2D
# Index: 406, Layer Name: activation_101, Layer Type: Activation
# Index: 407, Layer Name: reduction_add_1_reduce_6, Layer Type: Add
# Index: 408, Layer Name: separable_conv_1_reduction_right2_reduce_6, Layer Type: SeparableConv2D
# Index: 409, Layer Name: separable_conv_1_pad_reduction_right3_reduce_6, Layer Type: ZeroPadding2D
# Index: 410, Layer Name: activation_103, Layer Type: Activation
# Index: 411, Layer Name: separable_conv_1_bn_reduction_right2_reduce_6, Layer Type: BatchNormalization
# Index: 412, Layer Name: separable_conv_1_reduction_right3_reduce_6, Layer Type: SeparableConv2D
# Index: 413, Layer Name: separable_conv_1_reduction_left4_reduce_6, Layer Type: SeparableConv2D
# Index: 414, Layer Name: activation_100, Layer Type: Activation
# Index: 415, Layer Name: separable_conv_1_bn_reduction_right3_reduce_6, Layer Type: BatchNormalization
# Index: 416, Layer Name: separable_conv_1_bn_reduction_left4_reduce_6, Layer Type: BatchNormalization
# Index: 417, Layer Name: reduction_pad_1_reduce_6, Layer Type: ZeroPadding2D
# Index: 418, Layer Name: separable_conv_2_reduction_right2_reduce_6, Layer Type: SeparableConv2D
# Index: 419, Layer Name: activation_102, Layer Type: Activation
# Index: 420, Layer Name: activation_104, Layer Type: Activation
# Index: 421, Layer Name: reduction_left2_reduce_6, Layer Type: MaxPooling2D
# Index: 422, Layer Name: separable_conv_2_bn_reduction_right2_reduce_6, Layer Type: BatchNormalization
# Index: 423, Layer Name: separable_conv_2_reduction_right3_reduce_6, Layer Type: SeparableConv2D
# Index: 424, Layer Name: separable_conv_2_reduction_left4_reduce_6, Layer Type: SeparableConv2D
# Index: 425, Layer Name: adjust_relu_1_7, Layer Type: Activation
# Index: 426, Layer Name: reduction_add_2_reduce_6, Layer Type: Add
# Index: 427, Layer Name: reduction_left3_reduce_6, Layer Type: AveragePooling2D
# Index: 428, Layer Name: separable_conv_2_bn_reduction_right3_reduce_6, Layer Type: BatchNormalization
# Index: 429, Layer Name: reduction_left4_reduce_6, Layer Type: AveragePooling2D
# Index: 430, Layer Name: separable_conv_2_bn_reduction_left4_reduce_6, Layer Type: BatchNormalization
# Index: 431, Layer Name: reduction_right5_reduce_6, Layer Type: MaxPooling2D
# Index: 432, Layer Name: zero_padding2d_2, Layer Type: ZeroPadding2D
# Index: 433, Layer Name: reduction_add3_reduce_6, Layer Type: Add
# Index: 434, Layer Name: add_2, Layer Type: Add
# Index: 435, Layer Name: reduction_add4_reduce_6, Layer Type: Add
# Index: 436, Layer Name: cropping2d_2, Layer Type: Cropping2D
# Index: 437, Layer Name: reduction_concat_reduce_6, Layer Type: Concatenate
# Index: 438, Layer Name: adjust_avg_pool_1_7, Layer Type: AveragePooling2D
# Index: 439, Layer Name: adjust_avg_pool_2_7, Layer Type: AveragePooling2D
# Index: 440, Layer Name: adjust_conv_1_7, Layer Type: Conv2D
# Index: 441, Layer Name: adjust_conv_2_7, Layer Type: Conv2D
# Index: 442, Layer Name: activation_105, Layer Type: Activation
# Index: 443, Layer Name: concatenate_2, Layer Type: Concatenate
# Index: 444, Layer Name: normal_conv_1_7, Layer Type: Conv2D
# Index: 445, Layer Name: adjust_bn_7, Layer Type: BatchNormalization
# Index: 446, Layer Name: normal_bn_1_7, Layer Type: BatchNormalization
# Index: 447, Layer Name: activation_106, Layer Type: Activation
# Index: 448, Layer Name: activation_108, Layer Type: Activation
# Index: 449, Layer Name: activation_110, Layer Type: Activation
# Index: 450, Layer Name: activation_112, Layer Type: Activation
# Index: 451, Layer Name: activation_114, Layer Type: Activation
# Index: 452, Layer Name: separable_conv_1_normal_left1_7, Layer Type: SeparableConv2D
# Index: 453, Layer Name: separable_conv_1_normal_right1_7, Layer Type: SeparableConv2D
# Index: 454, Layer Name: separable_conv_1_normal_left2_7, Layer Type: SeparableConv2D
# Index: 455, Layer Name: separable_conv_1_normal_right2_7, Layer Type: SeparableConv2D
# Index: 456, Layer Name: separable_conv_1_normal_left5_7, Layer Type: SeparableConv2D
# Index: 457, Layer Name: separable_conv_1_bn_normal_left1_7, Layer Type: BatchNormalization
# Index: 458, Layer Name: separable_conv_1_bn_normal_right1_7, Layer Type: BatchNormalization
# Index: 459, Layer Name: separable_conv_1_bn_normal_left2_7, Layer Type: BatchNormalization
# Index: 460, Layer Name: separable_conv_1_bn_normal_right2_7, Layer Type: BatchNormalization
# Index: 461, Layer Name: separable_conv_1_bn_normal_left5_7, Layer Type: BatchNormalization
# Index: 462, Layer Name: activation_107, Layer Type: Activation
# Index: 463, Layer Name: activation_109, Layer Type: Activation
# Index: 464, Layer Name: activation_111, Layer Type: Activation
# Index: 465, Layer Name: activation_113, Layer Type: Activation
# Index: 466, Layer Name: activation_115, Layer Type: Activation
# Index: 467, Layer Name: separable_conv_2_normal_left1_7, Layer Type: SeparableConv2D
# Index: 468, Layer Name: separable_conv_2_normal_right1_7, Layer Type: SeparableConv2D
# Index: 469, Layer Name: separable_conv_2_normal_left2_7, Layer Type: SeparableConv2D
# Index: 470, Layer Name: separable_conv_2_normal_right2_7, Layer Type: SeparableConv2D
# Index: 471, Layer Name: separable_conv_2_normal_left5_7, Layer Type: SeparableConv2D
# Index: 472, Layer Name: separable_conv_2_bn_normal_left1_7, Layer Type: BatchNormalization
# Index: 473, Layer Name: separable_conv_2_bn_normal_right1_7, Layer Type: BatchNormalization
# Index: 474, Layer Name: separable_conv_2_bn_normal_left2_7, Layer Type: BatchNormalization
# Index: 475, Layer Name: separable_conv_2_bn_normal_right2_7, Layer Type: BatchNormalization
# Index: 476, Layer Name: normal_left3_7, Layer Type: AveragePooling2D
# Index: 477, Layer Name: normal_left4_7, Layer Type: AveragePooling2D
# Index: 478, Layer Name: normal_right4_7, Layer Type: AveragePooling2D
# Index: 479, Layer Name: separable_conv_2_bn_normal_left5_7, Layer Type: BatchNormalization
# Index: 480, Layer Name: normal_add_1_7, Layer Type: Add
# Index: 481, Layer Name: normal_add_2_7, Layer Type: Add
# Index: 482, Layer Name: normal_add_3_7, Layer Type: Add
# Index: 483, Layer Name: normal_add_4_7, Layer Type: Add
# Index: 484, Layer Name: normal_add_5_7, Layer Type: Add
# Index: 485, Layer Name: normal_concat_7, Layer Type: Concatenate
# Index: 486, Layer Name: activation_116, Layer Type: Activation
# Index: 487, Layer Name: activation_117, Layer Type: Activation
# Index: 488, Layer Name: adjust_conv_projection_8, Layer Type: Conv2D
# Index: 489, Layer Name: normal_conv_1_8, Layer Type: Conv2D
# Index: 490, Layer Name: adjust_bn_8, Layer Type: BatchNormalization
# Index: 491, Layer Name: normal_bn_1_8, Layer Type: BatchNormalization
# Index: 492, Layer Name: activation_118, Layer Type: Activation
# Index: 493, Layer Name: activation_120, Layer Type: Activation
# Index: 494, Layer Name: activation_122, Layer Type: Activation
# Index: 495, Layer Name: activation_124, Layer Type: Activation
# Index: 496, Layer Name: activation_126, Layer Type: Activation
# Index: 497, Layer Name: separable_conv_1_normal_left1_8, Layer Type: SeparableConv2D
# Index: 498, Layer Name: separable_conv_1_normal_right1_8, Layer Type: SeparableConv2D
# Index: 499, Layer Name: separable_conv_1_normal_left2_8, Layer Type: SeparableConv2D
# Index: 500, Layer Name: separable_conv_1_normal_right2_8, Layer Type: SeparableConv2D
# Index: 501, Layer Name: separable_conv_1_normal_left5_8, Layer Type: SeparableConv2D
# Index: 502, Layer Name: separable_conv_1_bn_normal_left1_8, Layer Type: BatchNormalization
# Index: 503, Layer Name: separable_conv_1_bn_normal_right1_8, Layer Type: BatchNormalization
# Index: 504, Layer Name: separable_conv_1_bn_normal_left2_8, Layer Type: BatchNormalization
# Index: 505, Layer Name: separable_conv_1_bn_normal_right2_8, Layer Type: BatchNormalization
# Index: 506, Layer Name: separable_conv_1_bn_normal_left5_8, Layer Type: BatchNormalization
# Index: 507, Layer Name: activation_119, Layer Type: Activation
# Index: 508, Layer Name: activation_121, Layer Type: Activation
# Index: 509, Layer Name: activation_123, Layer Type: Activation
# Index: 510, Layer Name: activation_125, Layer Type: Activation
# Index: 511, Layer Name: activation_127, Layer Type: Activation
# Index: 512, Layer Name: separable_conv_2_normal_left1_8, Layer Type: SeparableConv2D
# Index: 513, Layer Name: separable_conv_2_normal_right1_8, Layer Type: SeparableConv2D
# Index: 514, Layer Name: separable_conv_2_normal_left2_8, Layer Type: SeparableConv2D
# Index: 515, Layer Name: separable_conv_2_normal_right2_8, Layer Type: SeparableConv2D
# Index: 516, Layer Name: separable_conv_2_normal_left5_8, Layer Type: SeparableConv2D
# Index: 517, Layer Name: separable_conv_2_bn_normal_left1_8, Layer Type: BatchNormalization
# Index: 518, Layer Name: separable_conv_2_bn_normal_right1_8, Layer Type: BatchNormalization
# Index: 519, Layer Name: separable_conv_2_bn_normal_left2_8, Layer Type: BatchNormalization
# Index: 520, Layer Name: separable_conv_2_bn_normal_right2_8, Layer Type: BatchNormalization
# Index: 521, Layer Name: normal_left3_8, Layer Type: AveragePooling2D
# Index: 522, Layer Name: normal_left4_8, Layer Type: AveragePooling2D
# Index: 523, Layer Name: normal_right4_8, Layer Type: AveragePooling2D
# Index: 524, Layer Name: separable_conv_2_bn_normal_left5_8, Layer Type: BatchNormalization
# Index: 525, Layer Name: normal_add_1_8, Layer Type: Add
# Index: 526, Layer Name: normal_add_2_8, Layer Type: Add
# Index: 527, Layer Name: normal_add_3_8, Layer Type: Add
# Index: 528, Layer Name: normal_add_4_8, Layer Type: Add
# Index: 529, Layer Name: normal_add_5_8, Layer Type: Add
# Index: 530, Layer Name: normal_concat_8, Layer Type: Concatenate
# Index: 531, Layer Name: activation_128, Layer Type: Activation
# Index: 532, Layer Name: activation_129, Layer Type: Activation
# Index: 533, Layer Name: adjust_conv_projection_9, Layer Type: Conv2D
# Index: 534, Layer Name: normal_conv_1_9, Layer Type: Conv2D
# Index: 535, Layer Name: adjust_bn_9, Layer Type: BatchNormalization
# Index: 536, Layer Name: normal_bn_1_9, Layer Type: BatchNormalization
# Index: 537, Layer Name: activation_130, Layer Type: Activation
# Index: 538, Layer Name: activation_132, Layer Type: Activation
# Index: 539, Layer Name: activation_134, Layer Type: Activation
# Index: 540, Layer Name: activation_136, Layer Type: Activation
# Index: 541, Layer Name: activation_138, Layer Type: Activation
# Index: 542, Layer Name: separable_conv_1_normal_left1_9, Layer Type: SeparableConv2D
# Index: 543, Layer Name: separable_conv_1_normal_right1_9, Layer Type: SeparableConv2D
# Index: 544, Layer Name: separable_conv_1_normal_left2_9, Layer Type: SeparableConv2D
# Index: 545, Layer Name: separable_conv_1_normal_right2_9, Layer Type: SeparableConv2D
# Index: 546, Layer Name: separable_conv_1_normal_left5_9, Layer Type: SeparableConv2D
# Index: 547, Layer Name: separable_conv_1_bn_normal_left1_9, Layer Type: BatchNormalization
# Index: 548, Layer Name: separable_conv_1_bn_normal_right1_9, Layer Type: BatchNormalization
# Index: 549, Layer Name: separable_conv_1_bn_normal_left2_9, Layer Type: BatchNormalization
# Index: 550, Layer Name: separable_conv_1_bn_normal_right2_9, Layer Type: BatchNormalization
# Index: 551, Layer Name: separable_conv_1_bn_normal_left5_9, Layer Type: BatchNormalization
# Index: 552, Layer Name: activation_131, Layer Type: Activation
# Index: 553, Layer Name: activation_133, Layer Type: Activation
# Index: 554, Layer Name: activation_135, Layer Type: Activation
# Index: 555, Layer Name: activation_137, Layer Type: Activation
# Index: 556, Layer Name: activation_139, Layer Type: Activation
# Index: 557, Layer Name: separable_conv_2_normal_left1_9, Layer Type: SeparableConv2D
# Index: 558, Layer Name: separable_conv_2_normal_right1_9, Layer Type: SeparableConv2D
# Index: 559, Layer Name: separable_conv_2_normal_left2_9, Layer Type: SeparableConv2D
# Index: 560, Layer Name: separable_conv_2_normal_right2_9, Layer Type: SeparableConv2D
# Index: 561, Layer Name: separable_conv_2_normal_left5_9, Layer Type: SeparableConv2D
# Index: 562, Layer Name: separable_conv_2_bn_normal_left1_9, Layer Type: BatchNormalization
# Index: 563, Layer Name: separable_conv_2_bn_normal_right1_9, Layer Type: BatchNormalization
# Index: 564, Layer Name: separable_conv_2_bn_normal_left2_9, Layer Type: BatchNormalization
# Index: 565, Layer Name: separable_conv_2_bn_normal_right2_9, Layer Type: BatchNormalization
# Index: 566, Layer Name: normal_left3_9, Layer Type: AveragePooling2D
# Index: 567, Layer Name: normal_left4_9, Layer Type: AveragePooling2D
# Index: 568, Layer Name: normal_right4_9, Layer Type: AveragePooling2D
# Index: 569, Layer Name: separable_conv_2_bn_normal_left5_9, Layer Type: BatchNormalization
# Index: 570, Layer Name: normal_add_1_9, Layer Type: Add
# Index: 571, Layer Name: normal_add_2_9, Layer Type: Add
# Index: 572, Layer Name: normal_add_3_9, Layer Type: Add
# Index: 573, Layer Name: normal_add_4_9, Layer Type: Add
# Index: 574, Layer Name: normal_add_5_9, Layer Type: Add
# Index: 575, Layer Name: normal_concat_9, Layer Type: Concatenate
# Index: 576, Layer Name: activation_140, Layer Type: Activation
# Index: 577, Layer Name: activation_141, Layer Type: Activation
# Index: 578, Layer Name: adjust_conv_projection_10, Layer Type: Conv2D
# Index: 579, Layer Name: normal_conv_1_10, Layer Type: Conv2D
# Index: 580, Layer Name: adjust_bn_10, Layer Type: BatchNormalization
# Index: 581, Layer Name: normal_bn_1_10, Layer Type: BatchNormalization
# Index: 582, Layer Name: activation_142, Layer Type: Activation
# Index: 583, Layer Name: activation_144, Layer Type: Activation
# Index: 584, Layer Name: activation_146, Layer Type: Activation
# Index: 585, Layer Name: activation_148, Layer Type: Activation
# Index: 586, Layer Name: activation_150, Layer Type: Activation
# Index: 587, Layer Name: separable_conv_1_normal_left1_10, Layer Type: SeparableConv2D
# Index: 588, Layer Name: separable_conv_1_normal_right1_10, Layer Type: SeparableConv2D
# Index: 589, Layer Name: separable_conv_1_normal_left2_10, Layer Type: SeparableConv2D
# Index: 590, Layer Name: separable_conv_1_normal_right2_10, Layer Type: SeparableConv2D
# Index: 591, Layer Name: separable_conv_1_normal_left5_10, Layer Type: SeparableConv2D
# Index: 592, Layer Name: separable_conv_1_bn_normal_left1_10, Layer Type: BatchNormalization
# Index: 593, Layer Name: separable_conv_1_bn_normal_right1_10, Layer Type: BatchNormalization
# Index: 594, Layer Name: separable_conv_1_bn_normal_left2_10, Layer Type: BatchNormalization
# Index: 595, Layer Name: separable_conv_1_bn_normal_right2_10, Layer Type: BatchNormalization
# Index: 596, Layer Name: separable_conv_1_bn_normal_left5_10, Layer Type: BatchNormalization
# Index: 597, Layer Name: activation_143, Layer Type: Activation
# Index: 598, Layer Name: activation_145, Layer Type: Activation
# Index: 599, Layer Name: activation_147, Layer Type: Activation
# Index: 600, Layer Name: activation_149, Layer Type: Activation
# Index: 601, Layer Name: activation_151, Layer Type: Activation
# Index: 602, Layer Name: separable_conv_2_normal_left1_10, Layer Type: SeparableConv2D
# Index: 603, Layer Name: separable_conv_2_normal_right1_10, Layer Type: SeparableConv2D
# Index: 604, Layer Name: separable_conv_2_normal_left2_10, Layer Type: SeparableConv2D
# Index: 605, Layer Name: separable_conv_2_normal_right2_10, Layer Type: SeparableConv2D
# Index: 606, Layer Name: separable_conv_2_normal_left5_10, Layer Type: SeparableConv2D
# Index: 607, Layer Name: separable_conv_2_bn_normal_left1_10, Layer Type: BatchNormalization
# Index: 608, Layer Name: separable_conv_2_bn_normal_right1_10, Layer Type: BatchNormalization
# Index: 609, Layer Name: separable_conv_2_bn_normal_left2_10, Layer Type: BatchNormalization
# Index: 610, Layer Name: separable_conv_2_bn_normal_right2_10, Layer Type: BatchNormalization
# Index: 611, Layer Name: normal_left3_10, Layer Type: AveragePooling2D
# Index: 612, Layer Name: normal_left4_10, Layer Type: AveragePooling2D
# Index: 613, Layer Name: normal_right4_10, Layer Type: AveragePooling2D
# Index: 614, Layer Name: separable_conv_2_bn_normal_left5_10, Layer Type: BatchNormalization
# Index: 615, Layer Name: normal_add_1_10, Layer Type: Add
# Index: 616, Layer Name: normal_add_2_10, Layer Type: Add
# Index: 617, Layer Name: normal_add_3_10, Layer Type: Add
# Index: 618, Layer Name: normal_add_4_10, Layer Type: Add
# Index: 619, Layer Name: normal_add_5_10, Layer Type: Add
# Index: 620, Layer Name: normal_concat_10, Layer Type: Concatenate
# Index: 621, Layer Name: activation_152, Layer Type: Activation
# Index: 622, Layer Name: activation_153, Layer Type: Activation
# Index: 623, Layer Name: adjust_conv_projection_11, Layer Type: Conv2D
# Index: 624, Layer Name: normal_conv_1_11, Layer Type: Conv2D
# Index: 625, Layer Name: adjust_bn_11, Layer Type: BatchNormalization
# Index: 626, Layer Name: normal_bn_1_11, Layer Type: BatchNormalization
# Index: 627, Layer Name: activation_154, Layer Type: Activation
# Index: 628, Layer Name: activation_156, Layer Type: Activation
# Index: 629, Layer Name: activation_158, Layer Type: Activation
# Index: 630, Layer Name: activation_160, Layer Type: Activation
# Index: 631, Layer Name: activation_162, Layer Type: Activation
# Index: 632, Layer Name: separable_conv_1_normal_left1_11, Layer Type: SeparableConv2D
# Index: 633, Layer Name: separable_conv_1_normal_right1_11, Layer Type: SeparableConv2D
# Index: 634, Layer Name: separable_conv_1_normal_left2_11, Layer Type: SeparableConv2D
# Index: 635, Layer Name: separable_conv_1_normal_right2_11, Layer Type: SeparableConv2D
# ...
# Index: 989, Layer Name: normal_add_3_17, Layer Type: Add
# Index: 990, Layer Name: normal_add_4_17, Layer Type: Add
# Index: 991, Layer Name: normal_add_5_17, Layer Type: Add
# Index: 992, Layer Name: normal_concat_17, Layer Type: Concatenate
# Index: 993, Layer Name: activation_247, Layer Type: Activation
# Index: 994, Layer Name: activation_248, Layer Type: Activation
# Index: 995, Layer Name: adjust_conv_projection_18, Layer Type: Conv2D
# Index: 996, Layer Name: normal_conv_1_18, Layer Type: Conv2D
# Index: 997, Layer Name: adjust_bn_18, Layer Type: BatchNormalization
# Index: 998, Layer Name: normal_bn_1_18, Layer Type: BatchNormalization
# Index: 999, Layer Name: activation_249, Layer Type: Activation
# Index: 1000, Layer Name: activation_251, Layer Type: Activation
# Index: 1001, Layer Name: activation_253, Layer Type: Activation
# Index: 1002, Layer Name: activation_255, Layer Type: Activation
# Index: 1003, Layer Name: activation_257, Layer Type: Activation
# Index: 1004, Layer Name: separable_conv_1_normal_left1_18, Layer Type: SeparableConv2D
# Index: 1005, Layer Name: separable_conv_1_normal_right1_18, Layer Type: SeparableConv2D
# Index: 1006, Layer Name: separable_conv_1_normal_left2_18, Layer Type: SeparableConv2D
# Index: 1007, Layer Name: separable_conv_1_normal_right2_18, Layer Type: SeparableConv2D
# Index: 1008, Layer Name: separable_conv_1_normal_left5_18, Layer Type: SeparableConv2D
# Index: 1009, Layer Name: separable_conv_1_bn_normal_left1_18, Layer Type: BatchNormalization
# Index: 1010, Layer Name: separable_conv_1_bn_normal_right1_18, Layer Type: BatchNormalization
# Index: 1011, Layer Name: separable_conv_1_bn_normal_left2_18, Layer Type: BatchNormalization
# Index: 1012, Layer Name: separable_conv_1_bn_normal_right2_18, Layer Type: BatchNormalization
# Index: 1013, Layer Name: separable_conv_1_bn_normal_left5_18, Layer Type: BatchNormalization
# Index: 1014, Layer Name: activation_250, Layer Type: Activation
# Index: 1015, Layer Name: activation_252, Layer Type: Activation
# Index: 1016, Layer Name: activation_254, Layer Type: Activation
# Index: 1017, Layer Name: activation_256, Layer Type: Activation
# Index: 1018, Layer Name: activation_258, Layer Type: Activation
# Index: 1019, Layer Name: separable_conv_2_normal_left1_18, Layer Type: SeparableConv2D
# Index: 1020, Layer Name: separable_conv_2_normal_right1_18, Layer Type: SeparableConv2D
# Index: 1021, Layer Name: separable_conv_2_normal_left2_18, Layer Type: SeparableConv2D
# Index: 1022, Layer Name: separable_conv_2_normal_right2_18, Layer Type: SeparableConv2D
# Index: 1023, Layer Name: separable_conv_2_normal_left5_18, Layer Type: SeparableConv2D
# Index: 1024, Layer Name: separable_conv_2_bn_normal_left1_18, Layer Type: BatchNormalization
# Index: 1025, Layer Name: separable_conv_2_bn_normal_right1_18, Layer Type: BatchNormalization
# Index: 1026, Layer Name: separable_conv_2_bn_normal_left2_18, Layer Type: BatchNormalization
# Index: 1027, Layer Name: separable_conv_2_bn_normal_right2_18, Layer Type: BatchNormalization
# Index: 1028, Layer Name: normal_left3_18, Layer Type: AveragePooling2D
# Index: 1029, Layer Name: normal_left4_18, Layer Type: AveragePooling2D
# Index: 1030, Layer Name: normal_right4_18, Layer Type: AveragePooling2D
# Index: 1031, Layer Name: separable_conv_2_bn_normal_left5_18, Layer Type: BatchNormalization
# Index: 1032, Layer Name: normal_add_1_18, Layer Type: Add
# Index: 1033, Layer Name: normal_add_2_18, Layer Type: Add
# Index: 1034, Layer Name: normal_add_3_18, Layer Type: Add
# Index: 1035, Layer Name: normal_add_4_18, Layer Type: Add
# Index: 1036, Layer Name: normal_add_5_18, Layer Type: Add
# Index: 1037, Layer Name: normal_concat_18, Layer Type: Concatenate
# Index: 1038, Layer Name: activation_259, Layer Type: Activation
# Epoch 1/200
# 334/334 [==============================] - ETA: 0s - loss: 9.9062 - accuracy: 0.6738
# Epoch 1: val_accuracy improved from -inf to 0.68112, saving model to NASNetLarge.h5
# 334/334 [==============================] - 845s 2s/step - loss: 9.9062 - accuracy: 0.6738 - val_loss: 11.2687 - val_accuracy: 0.6811 - lr: 0.0010
# Epoch 2/200
# 334/334 [==============================] - ETA: 0s - loss: 3.4387 - accuracy: 0.8651
# Epoch 2: val_accuracy improved from 0.68112 to 0.74163, saving model to NASNetLarge.h5
# 334/334 [==============================] - 532s 2s/step - loss: 3.4387 - accuracy: 0.8651 - val_loss: 9.9709 - val_accuracy: 0.7416 - lr: 0.0010
# Epoch 3/200
# 334/334 [==============================] - ETA: 0s - loss: 1.9575 - accuracy: 0.9186
# Epoch 3: val_accuracy improved from 0.74163 to 0.75412, saving model to NASNetLarge.h5
# 334/334 [==============================] - 613s 2s/step - loss: 1.9575 - accuracy: 0.9186 - val_loss: 10.8787 - val_accuracy: 0.7541 - lr: 0.0010
# Epoch 4/200
# 334/334 [==============================] - ETA: 0s - loss: 1.6352 - accuracy: 0.9334
# Epoch 4: val_accuracy did not improve from 0.75412
# 334/334 [==============================] - 489s 1s/step - loss: 1.6352 - accuracy: 0.9334 - val_loss: 16.3887 - val_accuracy: 0.7258 - lr: 0.0010
# Epoch 5/200
# 334/334 [==============================] - ETA: 0s - loss: 1.2475 - accuracy: 0.9502
# Epoch 5: val_accuracy did not improve from 0.75412
# 334/334 [==============================] - 342s 1s/step - loss: 1.2475 - accuracy: 0.9502 - val_loss: 15.1320 - val_accuracy: 0.7400 - lr: 0.0010
# Epoch 6/200
# 334/334 [==============================] - ETA: 0s - loss: 1.3058 - accuracy: 0.9509
# Epoch 6: val_accuracy did not improve from 0.75412
# 334/334 [==============================] - 489s 1s/step - loss: 1.3058 - accuracy: 0.9509 - val_loss: 15.7631 - val_accuracy: 0.7479 - lr: 0.0010
# Epoch 7/200
# 334/334 [==============================] - ETA: 0s - loss: 1.1927 - accuracy: 0.9582
# Epoch 7: val_accuracy did not improve from 0.75412
# 334/334 [==============================] - 458s 1s/step - loss: 1.1927 - accuracy: 0.9582 - val_loss: 16.2538 - val_accuracy: 0.7527 - lr: 0.0010
# Epoch 8/200
# 334/334 [==============================] - ETA: 0s - loss: 1.0263 - accuracy: 0.9634
# Epoch 8: val_accuracy did not improve from 0.75412
# 334/334 [==============================] - 329s 984ms/step - loss: 1.0263 - accuracy: 0.9634 - val_loss: 18.8300 - val_accuracy: 0.7297 - lr: 0.0010
# Epoch 9/200
# 334/334 [==============================] - ETA: 0s - loss: 1.0114 - accuracy: 0.9668
# Epoch 9: val_accuracy did not improve from 0.75412
# 334/334 [==============================] - 333s 995ms/step - loss: 1.0114 - accuracy: 0.9668 - val_loss: 19.4060 - val_accuracy: 0.7504 - lr: 0.0010
# Epoch 10/200
# 334/334 [==============================] - ETA: 0s - loss: 0.9121 - accuracy: 0.9705
# Epoch 10: val_accuracy improved from 0.75412 to 0.75813, saving model to NASNetLarge.h5
# 334/334 [==============================] - 463s 1s/step - loss: 0.9121 - accuracy: 0.9705 - val_loss: 19.5975 - val_accuracy: 0.7581 - lr: 0.0010
# Epoch 11/200
# 334/334 [==============================] - ETA: 0s - loss: 0.9465 - accuracy: 0.9713
# Epoch 11: val_accuracy improved from 0.75813 to 0.76875, saving model to NASNetLarge.h5
# 334/334 [==============================] - 570s 2s/step - loss: 0.9465 - accuracy: 0.9713 - val_loss: 20.0290 - val_accuracy: 0.7688 - lr: 0.0010
# Epoch 12/200
# 334/334 [==============================] - ETA: 0s - loss: 0.7267 - accuracy: 0.9771
# Epoch 12: val_accuracy did not improve from 0.76875
# 334/334 [==============================] - 595s 2s/step - loss: 0.7267 - accuracy: 0.9771 - val_loss: 20.8571 - val_accuracy: 0.7649 - lr: 0.0010
# Epoch 13/200
# 334/334 [==============================] - ETA: 0s - loss: 0.8180 - accuracy: 0.9757
# Epoch 13: val_accuracy did not improve from 0.76875
# 334/334 [==============================] - 593s 2s/step - loss: 0.8180 - accuracy: 0.9757 - val_loss: 23.7963 - val_accuracy: 0.7579 - lr: 0.0010
# Epoch 14/200
# 334/334 [==============================] - ETA: 0s - loss: 0.8659 - accuracy: 0.9737
# Epoch 14: val_accuracy did not improve from 0.76875
# 334/334 [==============================] - 661s 2s/step - loss: 0.8659 - accuracy: 0.9737 - val_loss: 22.4007 - val_accuracy: 0.7678 - lr: 0.0010
# Epoch 15/200
# 334/334 [==============================] - ETA: 0s - loss: 0.8020 - accuracy: 0.9773
# Epoch 15: val_accuracy did not improve from 0.76875
# 334/334 [==============================] - 835s 2s/step - loss: 0.8020 - accuracy: 0.9773 - val_loss: 26.0913 - val_accuracy: 0.7516 - lr: 0.0010
# Epoch 16/200
# 334/334 [==============================] - ETA: 0s - loss: 0.8852 - accuracy: 0.9778
# Epoch 16: val_accuracy did not improve from 0.76875
# 334/334 [==============================] - 605s 2s/step - loss: 0.8852 - accuracy: 0.9778 - val_loss: 24.1828 - val_accuracy: 0.7674 - lr: 0.0010
# Epoch 17/200
# 334/334 [==============================] - ETA: 0s - loss: 0.6124 - accuracy: 0.9831
# Epoch 17: val_accuracy did not improve from 0.76875
# 334/334 [==============================] - 346s 1s/step - loss: 0.6124 - accuracy: 0.9831 - val_loss: 29.7280 - val_accuracy: 0.7485 - lr: 0.0010
# Epoch 18/200
# 334/334 [==============================] - ETA: 0s - loss: 0.5513 - accuracy: 0.9857
# Epoch 18: val_accuracy did not improve from 0.76875
# 334/334 [==============================] - 361s 1s/step - loss: 0.5513 - accuracy: 0.9857 - val_loss: 28.0703 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 19/200
# 334/334 [==============================] - ETA: 0s - loss: 0.6221 - accuracy: 0.9837
# Epoch 19: val_accuracy did not improve from 0.76875
# 334/334 [==============================] - 597s 2s/step - loss: 0.6221 - accuracy: 0.9837 - val_loss: 27.6550 - val_accuracy: 0.7626 - lr: 0.0010
# Epoch 20/200
# 334/334 [==============================] - ETA: 0s - loss: 0.7172 - accuracy: 0.9833
# Epoch 20: val_accuracy improved from 0.76875 to 0.77613, saving model to NASNetLarge.h5
# 334/334 [==============================] - 608s 2s/step - loss: 0.7172 - accuracy: 0.9833 - val_loss: 27.9866 - val_accuracy: 0.7761 - lr: 0.0010
# Epoch 21/200
# 334/334 [==============================] - ETA: 0s - loss: 0.8131 - accuracy: 0.9814
# Epoch 21: val_accuracy did not improve from 0.77613
# 334/334 [==============================] - 457s 1s/step - loss: 0.8131 - accuracy: 0.9814 - val_loss: 29.6607 - val_accuracy: 0.7636 - lr: 0.0010
# Epoch 22/200
# 334/334 [==============================] - ETA: 0s - loss: 0.6037 - accuracy: 0.9855
# Epoch 22: val_accuracy did not improve from 0.77613
# 334/334 [==============================] - 326s 974ms/step - loss: 0.6037 - accuracy: 0.9855 - val_loss: 30.0909 - val_accuracy: 0.7656 - lr: 0.0010
# Epoch 23/200
# 334/334 [==============================] - ETA: 0s - loss: 0.5459 - accuracy: 0.9863
# Epoch 23: val_accuracy did not improve from 0.77613
# 334/334 [==============================] - 349s 1s/step - loss: 0.5459 - accuracy: 0.9863 - val_loss: 33.1532 - val_accuracy: 0.7541 - lr: 0.0010
# Epoch 24/200
# 334/334 [==============================] - ETA: 0s - loss: 0.5447 - accuracy: 0.9871
# Epoch 24: val_accuracy did not improve from 0.77613
# 334/334 [==============================] - 343s 1s/step - loss: 0.5447 - accuracy: 0.9871 - val_loss: 32.1228 - val_accuracy: 0.7667 - lr: 0.0010
# Epoch 25/200
# 334/334 [==============================] - ETA: 0s - loss: 0.4422 - accuracy: 0.9900
# Epoch 25: val_accuracy improved from 0.77613 to 0.78363, saving model to NASNetLarge.h5
# 334/334 [==============================] - 350s 1s/step - loss: 0.4422 - accuracy: 0.9900 - val_loss: 28.9326 - val_accuracy: 0.7836 - lr: 0.0010
# Epoch 26/200
# 334/334 [==============================] - ETA: 0s - loss: 0.3995 - accuracy: 0.9898
# Epoch 26: val_accuracy did not improve from 0.78363
# 334/334 [==============================] - 339s 1s/step - loss: 0.3995 - accuracy: 0.9898 - val_loss: 33.3889 - val_accuracy: 0.7682 - lr: 0.0010
# Epoch 27/200
# 334/334 [==============================] - ETA: 0s - loss: 0.5677 - accuracy: 0.9867
# Epoch 27: val_accuracy did not improve from 0.78363
# 334/334 [==============================] - 594s 2s/step - loss: 0.5677 - accuracy: 0.9867 - val_loss: 34.2482 - val_accuracy: 0.7701 - lr: 0.0010
# Epoch 28/200
# 334/334 [==============================] - ETA: 0s - loss: 0.5603 - accuracy: 0.9880
# Epoch 28: val_accuracy did not improve from 0.78363
# 334/334 [==============================] - 585s 2s/step - loss: 0.5603 - accuracy: 0.9880 - val_loss: 33.9643 - val_accuracy: 0.7739 - lr: 0.0010
# Epoch 29/200
# 334/334 [==============================] - ETA: 0s - loss: 0.5842 - accuracy: 0.9865
# Epoch 29: val_accuracy did not improve from 0.78363
# 334/334 [==============================] - 591s 2s/step - loss: 0.5842 - accuracy: 0.9865 - val_loss: 33.6453 - val_accuracy: 0.7663 - lr: 0.0010
# Epoch 30/200
# 334/334 [==============================] - ETA: 0s - loss: 0.5432 - accuracy: 0.9876
# Epoch 30: val_accuracy did not improve from 0.78363
# 334/334 [==============================] - 594s 2s/step - loss: 0.5432 - accuracy: 0.9876 - val_loss: 38.9833 - val_accuracy: 0.7641 - lr: 0.0010
# Epoch 31/200
# 334/334 [==============================] - ETA: 0s - loss: 0.3723 - accuracy: 0.9918
# Epoch 31: val_accuracy did not improve from 0.78363
# 334/334 [==============================] - 597s 2s/step - loss: 0.3723 - accuracy: 0.9918 - val_loss: 35.1887 - val_accuracy: 0.7731 - lr: 0.0010
# Epoch 32/200
# 334/334 [==============================] - ETA: 0s - loss: 0.4877 - accuracy: 0.9906
# Epoch 32: val_accuracy did not improve from 0.78363
# 334/334 [==============================] - 596s 2s/step - loss: 0.4877 - accuracy: 0.9906 - val_loss: 34.7759 - val_accuracy: 0.7742 - lr: 0.0010
# Epoch 33/200
# 334/334 [==============================] - ETA: 0s - loss: 0.3252 - accuracy: 0.9925
# Epoch 33: val_accuracy did not improve from 0.78363
# 334/334 [==============================] - 558s 2s/step - loss: 0.3252 - accuracy: 0.9925 - val_loss: 38.7795 - val_accuracy: 0.7605 - lr: 0.0010
# Epoch 34/200
# 334/334 [==============================] - ETA: 0s - loss: 0.4298 - accuracy: 0.9906
# Epoch 34: val_accuracy did not improve from 0.78363
# 334/334 [==============================] - 582s 2s/step - loss: 0.4298 - accuracy: 0.9906 - val_loss: 38.0573 - val_accuracy: 0.7690 - lr: 0.0010
# Epoch 35/200
# 334/334 [==============================] - ETA: 0s - loss: 0.4375 - accuracy: 0.9909
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Restoring model weights from the end of the best epoch: 25.
#
# Epoch 35: val_accuracy did not improve from 0.78363
# 334/334 [==============================] - 588s 2s/step - loss: 0.4375 - accuracy: 0.9909 - val_loss: 41.9160 - val_accuracy: 0.7609 - lr: 0.0010
# Epoch 35: early stopping
# Training Time: 304.85 minutes
# 84/84 [==============================] - 118s 1s/step
# 84/84 [==============================] - 116s 1s/step - loss: 28.9326 - accuracy: 0.7836
# Final Validation Accuracy: 0.7836
# Final Validation Loss: 28.9326
# 84/84 [==============================] - 115s 1s/step
# Confusion Matrix:
# [[740  10   1   8   0   0  21   2   1  17]
#  [ 47 512   5  98  32   3  36  45  17   5]
#  [  3   6 722   1   5   3   7  36  15   2]
#  [ 14  89   7 589  40   3  35  15   2   6]
#  [  6  41   7  24 612  22  36  35  13   4]
#  [  0  12   8   2  44 690  12   4  20   8]
#  [ 45  74   8  53  25   3 539  28  18   7]
#  [ 36  55  47  11  21   2  26 526  70   6]
#  [  7  17  28   9  25  16  28 105 559   6]
#  [  4   0   2   0   0   4   2   2   6 780]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.93      0.87       800
#            1       0.63      0.64      0.63       800
#            2       0.86      0.90      0.88       800
#            3       0.74      0.74      0.74       800
#            4       0.76      0.77      0.76       800
#            5       0.92      0.86      0.89       800
#            6       0.73      0.67      0.70       800
#            7       0.66      0.66      0.66       800
#            8       0.78      0.70      0.74       800
#            9       0.93      0.97      0.95       800
#
#     accuracy                           0.78      8000
#    macro avg       0.78      0.78      0.78      8000
# weighted avg       0.78      0.78      0.78      8000
