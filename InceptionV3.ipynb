# %%
#InceptionV3
import warnings
from sklearn.exceptions import UndefinedMetricWarning
# Suppress specific sklearn warning
warnings.filterwarnings("ignore", category=UndefinedMetricWarning)
import os
import time
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import  InceptionV3
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from sklearn.metrics import roc_curve, auc, confusion_matrix, classification_report
# Dataset and Parameters
dataset_dir ="./Tomato"
img_size = (299, 299)
batch_size = 96
num_classes = 10
# Data Generators
datagen = ImageDataGenerator(rescale=1.0 / 255, validation_split=0.2)
train_generator = datagen.flow_from_directory(
    dataset_dir, target_size=img_size, batch_size=batch_size, class_mode="categorical", subset="training", shuffle=True)
val_generator = datagen.flow_from_directory(
    dataset_dir, target_size=img_size, batch_size=batch_size, class_mode="categorical", subset="validation", shuffle=False)

# Load ResNet50 model without the top layer
base_model = InceptionV3(include_top=False, weights="imagenet", input_shape=(299, 299, 3))
base_model.trainable = False
for layer in base_model.layers[-5:]:
    layer.trainable = True

# Print ResNet50 layers
for idx, layer in enumerate(base_model.layers):
    print(f"Index: {idx}, Layer Name: {layer.name}, Layer Type: {layer.__class__.__name__}")

# Add custom classification head
flattened = Flatten()(base_model.output)
output = Dense(num_classes, activation="softmax")(flattened)
model = Model(inputs=base_model.input, outputs=output)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss="categorical_crossentropy", metrics=["accuracy"])

# Callbacks
reduce_lr = ReduceLROnPlateau(monitor="val_accuracy", factor=0.5, patience=10, verbose=1)
early_stop = EarlyStopping(monitor="val_accuracy", patience=10, restore_best_weights=True, verbose=1)
model_checkpoint = ModelCheckpoint("./InceptionV3.h5", monitor="val_accuracy", save_best_only=True, verbose=1)
callbacks = [reduce_lr, early_stop, model_checkpoint]

# Training
start_time = time.time()
history = model.fit(train_generator, validation_data=val_generator, epochs=200, callbacks=callbacks)
model.save("./InceptionV3.h5")
print(f"Training Time: {(time.time() - start_time) / 60:.2f} minutes")

# ROC Curve
y_pred = model.predict(val_generator, verbose=1)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = val_generator.classes
class_names = list(val_generator.class_indices.keys())
y_true_one_hot = to_categorical(y_true, num_classes=len(class_names))

fpr = {}
tpr_stage1 = {}
roc_auc = {}

plt.figure(figsize=(12, 8))
for i in range(len(class_names)):
    fpr[i], tpr_stage1[i], _ = roc_curve(y_true_one_hot[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr_stage1[i])
    plt.plot(fpr[i], tpr_stage1[i], label=f' {class_names[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# Plot Training History
def plot_history(history):
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(history.history["accuracy"], label="Training Accuracy")
    plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
    plt.title("Accuracy")
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(history.history["loss"], label="Training Loss")
    plt.plot(history.history["val_loss"], label="Validation Loss")
    plt.title("Loss")
    plt.legend()
    plt.show()

plot_history(history)

# Evaluate the Final Model
val_loss, val_acc = model.evaluate(val_generator)
print(f"Final Validation Accuracy: {val_acc:.4f}")
print(f"Final Validation Loss: {val_loss:.4f}")

# Confusion Matrix and Report
y_pred = model.predict(val_generator, batch_size=batch_size, verbose=1)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = val_generator.classes

conf_matrix = confusion_matrix(y_true, y_pred_classes)
print("Confusion Matrix:")
print(conf_matrix)

print("Classification Report:")
print(classification_report(y_true, y_pred_classes))

# Plot Confusion Matrix
def plot_confusion_matrix(cm, classes):
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=classes, yticklabels=classes)
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.title("Confusion Matrix")
    plt.show()

class_labels = list(val_generator.class_indices.keys())
plot_confusion_matrix(conf_matrix, class_labels)
# Out:
# Found 32000 images belonging to 10 classes.
# Found 8000 images belonging to 10 classes.
# Index: 0, Layer Name: input_2, Layer Type: InputLayer
# Index: 1, Layer Name: conv2d_94, Layer Type: Conv2D
# Index: 2, Layer Name: batch_normalization_94, Layer Type: BatchNormalization
# Index: 3, Layer Name: activation_94, Layer Type: Activation
# Index: 4, Layer Name: conv2d_95, Layer Type: Conv2D
# Index: 5, Layer Name: batch_normalization_95, Layer Type: BatchNormalization
# Index: 6, Layer Name: activation_95, Layer Type: Activation
# Index: 7, Layer Name: conv2d_96, Layer Type: Conv2D
# Index: 8, Layer Name: batch_normalization_96, Layer Type: BatchNormalization
# Index: 9, Layer Name: activation_96, Layer Type: Activation
# Index: 10, Layer Name: max_pooling2d_4, Layer Type: MaxPooling2D
# Index: 11, Layer Name: conv2d_97, Layer Type: Conv2D
# Index: 12, Layer Name: batch_normalization_97, Layer Type: BatchNormalization
# Index: 13, Layer Name: activation_97, Layer Type: Activation
# Index: 14, Layer Name: conv2d_98, Layer Type: Conv2D
# Index: 15, Layer Name: batch_normalization_98, Layer Type: BatchNormalization
# Index: 16, Layer Name: activation_98, Layer Type: Activation
# Index: 17, Layer Name: max_pooling2d_5, Layer Type: MaxPooling2D
# Index: 18, Layer Name: conv2d_102, Layer Type: Conv2D
# Index: 19, Layer Name: batch_normalization_102, Layer Type: BatchNormalization
# Index: 20, Layer Name: activation_102, Layer Type: Activation
# Index: 21, Layer Name: conv2d_100, Layer Type: Conv2D
# Index: 22, Layer Name: conv2d_103, Layer Type: Conv2D
# Index: 23, Layer Name: batch_normalization_100, Layer Type: BatchNormalization
# Index: 24, Layer Name: batch_normalization_103, Layer Type: BatchNormalization
# Index: 25, Layer Name: activation_100, Layer Type: Activation
# Index: 26, Layer Name: activation_103, Layer Type: Activation
# Index: 27, Layer Name: average_pooling2d_9, Layer Type: AveragePooling2D
# Index: 28, Layer Name: conv2d_99, Layer Type: Conv2D
# Index: 29, Layer Name: conv2d_101, Layer Type: Conv2D
# Index: 30, Layer Name: conv2d_104, Layer Type: Conv2D
# Index: 31, Layer Name: conv2d_105, Layer Type: Conv2D
# Index: 32, Layer Name: batch_normalization_99, Layer Type: BatchNormalization
# Index: 33, Layer Name: batch_normalization_101, Layer Type: BatchNormalization
# Index: 34, Layer Name: batch_normalization_104, Layer Type: BatchNormalization
# Index: 35, Layer Name: batch_normalization_105, Layer Type: BatchNormalization
# Index: 36, Layer Name: activation_99, Layer Type: Activation
# Index: 37, Layer Name: activation_101, Layer Type: Activation
# Index: 38, Layer Name: activation_104, Layer Type: Activation
# Index: 39, Layer Name: activation_105, Layer Type: Activation
# Index: 40, Layer Name: mixed0, Layer Type: Concatenate
# Index: 41, Layer Name: conv2d_109, Layer Type: Conv2D
# Index: 42, Layer Name: batch_normalization_109, Layer Type: BatchNormalization
# Index: 43, Layer Name: activation_109, Layer Type: Activation
# Index: 44, Layer Name: conv2d_107, Layer Type: Conv2D
# Index: 45, Layer Name: conv2d_110, Layer Type: Conv2D
# Index: 46, Layer Name: batch_normalization_107, Layer Type: BatchNormalization
# Index: 47, Layer Name: batch_normalization_110, Layer Type: BatchNormalization
# Index: 48, Layer Name: activation_107, Layer Type: Activation
# Index: 49, Layer Name: activation_110, Layer Type: Activation
# Index: 50, Layer Name: average_pooling2d_10, Layer Type: AveragePooling2D
# Index: 51, Layer Name: conv2d_106, Layer Type: Conv2D
# Index: 52, Layer Name: conv2d_108, Layer Type: Conv2D
# Index: 53, Layer Name: conv2d_111, Layer Type: Conv2D
# Index: 54, Layer Name: conv2d_112, Layer Type: Conv2D
# Index: 55, Layer Name: batch_normalization_106, Layer Type: BatchNormalization
# Index: 56, Layer Name: batch_normalization_108, Layer Type: BatchNormalization
# Index: 57, Layer Name: batch_normalization_111, Layer Type: BatchNormalization
# Index: 58, Layer Name: batch_normalization_112, Layer Type: BatchNormalization
# Index: 59, Layer Name: activation_106, Layer Type: Activation
# Index: 60, Layer Name: activation_108, Layer Type: Activation
# Index: 61, Layer Name: activation_111, Layer Type: Activation
# Index: 62, Layer Name: activation_112, Layer Type: Activation
# Index: 63, Layer Name: mixed1, Layer Type: Concatenate
# Index: 64, Layer Name: conv2d_116, Layer Type: Conv2D
# Index: 65, Layer Name: batch_normalization_116, Layer Type: BatchNormalization
# Index: 66, Layer Name: activation_116, Layer Type: Activation
# Index: 67, Layer Name: conv2d_114, Layer Type: Conv2D
# Index: 68, Layer Name: conv2d_117, Layer Type: Conv2D
# Index: 69, Layer Name: batch_normalization_114, Layer Type: BatchNormalization
# Index: 70, Layer Name: batch_normalization_117, Layer Type: BatchNormalization
# Index: 71, Layer Name: activation_114, Layer Type: Activation
# Index: 72, Layer Name: activation_117, Layer Type: Activation
# Index: 73, Layer Name: average_pooling2d_11, Layer Type: AveragePooling2D
# Index: 74, Layer Name: conv2d_113, Layer Type: Conv2D
# Index: 75, Layer Name: conv2d_115, Layer Type: Conv2D
# Index: 76, Layer Name: conv2d_118, Layer Type: Conv2D
# Index: 77, Layer Name: conv2d_119, Layer Type: Conv2D
# Index: 78, Layer Name: batch_normalization_113, Layer Type: BatchNormalization
# Index: 79, Layer Name: batch_normalization_115, Layer Type: BatchNormalization
# Index: 80, Layer Name: batch_normalization_118, Layer Type: BatchNormalization
# Index: 81, Layer Name: batch_normalization_119, Layer Type: BatchNormalization
# Index: 82, Layer Name: activation_113, Layer Type: Activation
# Index: 83, Layer Name: activation_115, Layer Type: Activation
# Index: 84, Layer Name: activation_118, Layer Type: Activation
# Index: 85, Layer Name: activation_119, Layer Type: Activation
# Index: 86, Layer Name: mixed2, Layer Type: Concatenate
# Index: 87, Layer Name: conv2d_121, Layer Type: Conv2D
# Index: 88, Layer Name: batch_normalization_121, Layer Type: BatchNormalization
# Index: 89, Layer Name: activation_121, Layer Type: Activation
# Index: 90, Layer Name: conv2d_122, Layer Type: Conv2D
# Index: 91, Layer Name: batch_normalization_122, Layer Type: BatchNormalization
# Index: 92, Layer Name: activation_122, Layer Type: Activation
# Index: 93, Layer Name: conv2d_120, Layer Type: Conv2D
# Index: 94, Layer Name: conv2d_123, Layer Type: Conv2D
# Index: 95, Layer Name: batch_normalization_120, Layer Type: BatchNormalization
# Index: 96, Layer Name: batch_normalization_123, Layer Type: BatchNormalization
# Index: 97, Layer Name: activation_120, Layer Type: Activation
# Index: 98, Layer Name: activation_123, Layer Type: Activation
# Index: 99, Layer Name: max_pooling2d_6, Layer Type: MaxPooling2D
# Index: 100, Layer Name: mixed3, Layer Type: Concatenate
# Index: 101, Layer Name: conv2d_128, Layer Type: Conv2D
# Index: 102, Layer Name: batch_normalization_128, Layer Type: BatchNormalization
# Index: 103, Layer Name: activation_128, Layer Type: Activation
# Index: 104, Layer Name: conv2d_129, Layer Type: Conv2D
# Index: 105, Layer Name: batch_normalization_129, Layer Type: BatchNormalization
# Index: 106, Layer Name: activation_129, Layer Type: Activation
# Index: 107, Layer Name: conv2d_125, Layer Type: Conv2D
# Index: 108, Layer Name: conv2d_130, Layer Type: Conv2D
# Index: 109, Layer Name: batch_normalization_125, Layer Type: BatchNormalization
# Index: 110, Layer Name: batch_normalization_130, Layer Type: BatchNormalization
# Index: 111, Layer Name: activation_125, Layer Type: Activation
# Index: 112, Layer Name: activation_130, Layer Type: Activation
# Index: 113, Layer Name: conv2d_126, Layer Type: Conv2D
# Index: 114, Layer Name: conv2d_131, Layer Type: Conv2D
# Index: 115, Layer Name: batch_normalization_126, Layer Type: BatchNormalization
# Index: 116, Layer Name: batch_normalization_131, Layer Type: BatchNormalization
# Index: 117, Layer Name: activation_126, Layer Type: Activation
# Index: 118, Layer Name: activation_131, Layer Type: Activation
# Index: 119, Layer Name: average_pooling2d_12, Layer Type: AveragePooling2D
# Index: 120, Layer Name: conv2d_124, Layer Type: Conv2D
# Index: 121, Layer Name: conv2d_127, Layer Type: Conv2D
# Index: 122, Layer Name: conv2d_132, Layer Type: Conv2D
# Index: 123, Layer Name: conv2d_133, Layer Type: Conv2D
# Index: 124, Layer Name: batch_normalization_124, Layer Type: BatchNormalization
# Index: 125, Layer Name: batch_normalization_127, Layer Type: BatchNormalization
# Index: 126, Layer Name: batch_normalization_132, Layer Type: BatchNormalization
# Index: 127, Layer Name: batch_normalization_133, Layer Type: BatchNormalization
# Index: 128, Layer Name: activation_124, Layer Type: Activation
# Index: 129, Layer Name: activation_127, Layer Type: Activation
# Index: 130, Layer Name: activation_132, Layer Type: Activation
# Index: 131, Layer Name: activation_133, Layer Type: Activation
# Index: 132, Layer Name: mixed4, Layer Type: Concatenate
# Index: 133, Layer Name: conv2d_138, Layer Type: Conv2D
# Index: 134, Layer Name: batch_normalization_138, Layer Type: BatchNormalization
# Index: 135, Layer Name: activation_138, Layer Type: Activation
# Index: 136, Layer Name: conv2d_139, Layer Type: Conv2D
# Index: 137, Layer Name: batch_normalization_139, Layer Type: BatchNormalization
# Index: 138, Layer Name: activation_139, Layer Type: Activation
# Index: 139, Layer Name: conv2d_135, Layer Type: Conv2D
# Index: 140, Layer Name: conv2d_140, Layer Type: Conv2D
# Index: 141, Layer Name: batch_normalization_135, Layer Type: BatchNormalization
# Index: 142, Layer Name: batch_normalization_140, Layer Type: BatchNormalization
# Index: 143, Layer Name: activation_135, Layer Type: Activation
# Index: 144, Layer Name: activation_140, Layer Type: Activation
# Index: 145, Layer Name: conv2d_136, Layer Type: Conv2D
# Index: 146, Layer Name: conv2d_141, Layer Type: Conv2D
# Index: 147, Layer Name: batch_normalization_136, Layer Type: BatchNormalization
# Index: 148, Layer Name: batch_normalization_141, Layer Type: BatchNormalization
# Index: 149, Layer Name: activation_136, Layer Type: Activation
# Index: 150, Layer Name: activation_141, Layer Type: Activation
# Index: 151, Layer Name: average_pooling2d_13, Layer Type: AveragePooling2D
# Index: 152, Layer Name: conv2d_134, Layer Type: Conv2D
# Index: 153, Layer Name: conv2d_137, Layer Type: Conv2D
# Index: 154, Layer Name: conv2d_142, Layer Type: Conv2D
# Index: 155, Layer Name: conv2d_143, Layer Type: Conv2D
# Index: 156, Layer Name: batch_normalization_134, Layer Type: BatchNormalization
# Index: 157, Layer Name: batch_normalization_137, Layer Type: BatchNormalization
# Index: 158, Layer Name: batch_normalization_142, Layer Type: BatchNormalization
# Index: 159, Layer Name: batch_normalization_143, Layer Type: BatchNormalization
# Index: 160, Layer Name: activation_134, Layer Type: Activation
# Index: 161, Layer Name: activation_137, Layer Type: Activation
# Index: 162, Layer Name: activation_142, Layer Type: Activation
# Index: 163, Layer Name: activation_143, Layer Type: Activation
# Index: 164, Layer Name: mixed5, Layer Type: Concatenate
# Index: 165, Layer Name: conv2d_148, Layer Type: Conv2D
# Index: 166, Layer Name: batch_normalization_148, Layer Type: BatchNormalization
# Index: 167, Layer Name: activation_148, Layer Type: Activation
# Index: 168, Layer Name: conv2d_149, Layer Type: Conv2D
# Index: 169, Layer Name: batch_normalization_149, Layer Type: BatchNormalization
# Index: 170, Layer Name: activation_149, Layer Type: Activation
# Index: 171, Layer Name: conv2d_145, Layer Type: Conv2D
# Index: 172, Layer Name: conv2d_150, Layer Type: Conv2D
# Index: 173, Layer Name: batch_normalization_145, Layer Type: BatchNormalization
# Index: 174, Layer Name: batch_normalization_150, Layer Type: BatchNormalization
# Index: 175, Layer Name: activation_145, Layer Type: Activation
# Index: 176, Layer Name: activation_150, Layer Type: Activation
# Index: 177, Layer Name: conv2d_146, Layer Type: Conv2D
# Index: 178, Layer Name: conv2d_151, Layer Type: Conv2D
# Index: 179, Layer Name: batch_normalization_146, Layer Type: BatchNormalization
# Index: 180, Layer Name: batch_normalization_151, Layer Type: BatchNormalization
# Index: 181, Layer Name: activation_146, Layer Type: Activation
# Index: 182, Layer Name: activation_151, Layer Type: Activation
# Index: 183, Layer Name: average_pooling2d_14, Layer Type: AveragePooling2D
# Index: 184, Layer Name: conv2d_144, Layer Type: Conv2D
# Index: 185, Layer Name: conv2d_147, Layer Type: Conv2D
# Index: 186, Layer Name: conv2d_152, Layer Type: Conv2D
# Index: 187, Layer Name: conv2d_153, Layer Type: Conv2D
# Index: 188, Layer Name: batch_normalization_144, Layer Type: BatchNormalization
# Index: 189, Layer Name: batch_normalization_147, Layer Type: BatchNormalization
# Index: 190, Layer Name: batch_normalization_152, Layer Type: BatchNormalization
# Index: 191, Layer Name: batch_normalization_153, Layer Type: BatchNormalization
# Index: 192, Layer Name: activation_144, Layer Type: Activation
# Index: 193, Layer Name: activation_147, Layer Type: Activation
# Index: 194, Layer Name: activation_152, Layer Type: Activation
# Index: 195, Layer Name: activation_153, Layer Type: Activation
# Index: 196, Layer Name: mixed6, Layer Type: Concatenate
# Index: 197, Layer Name: conv2d_158, Layer Type: Conv2D
# Index: 198, Layer Name: batch_normalization_158, Layer Type: BatchNormalization
# Index: 199, Layer Name: activation_158, Layer Type: Activation
# Index: 200, Layer Name: conv2d_159, Layer Type: Conv2D
# Index: 201, Layer Name: batch_normalization_159, Layer Type: BatchNormalization
# Index: 202, Layer Name: activation_159, Layer Type: Activation
# Index: 203, Layer Name: conv2d_155, Layer Type: Conv2D
# Index: 204, Layer Name: conv2d_160, Layer Type: Conv2D
# Index: 205, Layer Name: batch_normalization_155, Layer Type: BatchNormalization
# Index: 206, Layer Name: batch_normalization_160, Layer Type: BatchNormalization
# Index: 207, Layer Name: activation_155, Layer Type: Activation
# Index: 208, Layer Name: activation_160, Layer Type: Activation
# Index: 209, Layer Name: conv2d_156, Layer Type: Conv2D
# Index: 210, Layer Name: conv2d_161, Layer Type: Conv2D
# Index: 211, Layer Name: batch_normalization_156, Layer Type: BatchNormalization
# Index: 212, Layer Name: batch_normalization_161, Layer Type: BatchNormalization
# Index: 213, Layer Name: activation_156, Layer Type: Activation
# Index: 214, Layer Name: activation_161, Layer Type: Activation
# Index: 215, Layer Name: average_pooling2d_15, Layer Type: AveragePooling2D
# Index: 216, Layer Name: conv2d_154, Layer Type: Conv2D
# Index: 217, Layer Name: conv2d_157, Layer Type: Conv2D
# Index: 218, Layer Name: conv2d_162, Layer Type: Conv2D
# Index: 219, Layer Name: conv2d_163, Layer Type: Conv2D
# Index: 220, Layer Name: batch_normalization_154, Layer Type: BatchNormalization
# Index: 221, Layer Name: batch_normalization_157, Layer Type: BatchNormalization
# Index: 222, Layer Name: batch_normalization_162, Layer Type: BatchNormalization
# Index: 223, Layer Name: batch_normalization_163, Layer Type: BatchNormalization
# Index: 224, Layer Name: activation_154, Layer Type: Activation
# Index: 225, Layer Name: activation_157, Layer Type: Activation
# Index: 226, Layer Name: activation_162, Layer Type: Activation
# Index: 227, Layer Name: activation_163, Layer Type: Activation
# Index: 228, Layer Name: mixed7, Layer Type: Concatenate
# Index: 229, Layer Name: conv2d_166, Layer Type: Conv2D
# Index: 230, Layer Name: batch_normalization_166, Layer Type: BatchNormalization
# Index: 231, Layer Name: activation_166, Layer Type: Activation
# Index: 232, Layer Name: conv2d_167, Layer Type: Conv2D
# Index: 233, Layer Name: batch_normalization_167, Layer Type: BatchNormalization
# Index: 234, Layer Name: activation_167, Layer Type: Activation
# Index: 235, Layer Name: conv2d_164, Layer Type: Conv2D
# Index: 236, Layer Name: conv2d_168, Layer Type: Conv2D
# Index: 237, Layer Name: batch_normalization_164, Layer Type: BatchNormalization
# Index: 238, Layer Name: batch_normalization_168, Layer Type: BatchNormalization
# Index: 239, Layer Name: activation_164, Layer Type: Activation
# Index: 240, Layer Name: activation_168, Layer Type: Activation
# Index: 241, Layer Name: conv2d_165, Layer Type: Conv2D
# Index: 242, Layer Name: conv2d_169, Layer Type: Conv2D
# Index: 243, Layer Name: batch_normalization_165, Layer Type: BatchNormalization
# Index: 244, Layer Name: batch_normalization_169, Layer Type: BatchNormalization
# Index: 245, Layer Name: activation_165, Layer Type: Activation
# Index: 246, Layer Name: activation_169, Layer Type: Activation
# Index: 247, Layer Name: max_pooling2d_7, Layer Type: MaxPooling2D
# Index: 248, Layer Name: mixed8, Layer Type: Concatenate
# Index: 249, Layer Name: conv2d_174, Layer Type: Conv2D
# Index: 250, Layer Name: batch_normalization_174, Layer Type: BatchNormalization
# Index: 251, Layer Name: activation_174, Layer Type: Activation
# Index: 252, Layer Name: conv2d_171, Layer Type: Conv2D
# Index: 253, Layer Name: conv2d_175, Layer Type: Conv2D
# Index: 254, Layer Name: batch_normalization_171, Layer Type: BatchNormalization
# Index: 255, Layer Name: batch_normalization_175, Layer Type: BatchNormalization
# Index: 256, Layer Name: activation_171, Layer Type: Activation
# Index: 257, Layer Name: activation_175, Layer Type: Activation
# Index: 258, Layer Name: conv2d_172, Layer Type: Conv2D
# Index: 259, Layer Name: conv2d_173, Layer Type: Conv2D
# Index: 260, Layer Name: conv2d_176, Layer Type: Conv2D
# Index: 261, Layer Name: conv2d_177, Layer Type: Conv2D
# Index: 262, Layer Name: average_pooling2d_16, Layer Type: AveragePooling2D
# Index: 263, Layer Name: conv2d_170, Layer Type: Conv2D
# Index: 264, Layer Name: batch_normalization_172, Layer Type: BatchNormalization
# Index: 265, Layer Name: batch_normalization_173, Layer Type: BatchNormalization
# Index: 266, Layer Name: batch_normalization_176, Layer Type: BatchNormalization
# Index: 267, Layer Name: batch_normalization_177, Layer Type: BatchNormalization
# Index: 268, Layer Name: conv2d_178, Layer Type: Conv2D
# Index: 269, Layer Name: batch_normalization_170, Layer Type: BatchNormalization
# Index: 270, Layer Name: activation_172, Layer Type: Activation
# Index: 271, Layer Name: activation_173, Layer Type: Activation
# Index: 272, Layer Name: activation_176, Layer Type: Activation
# Index: 273, Layer Name: activation_177, Layer Type: Activation
# Index: 274, Layer Name: batch_normalization_178, Layer Type: BatchNormalization
# Index: 275, Layer Name: activation_170, Layer Type: Activation
# Index: 276, Layer Name: mixed9_0, Layer Type: Concatenate
# Index: 277, Layer Name: concatenate_2, Layer Type: Concatenate
# Index: 278, Layer Name: activation_178, Layer Type: Activation
# Index: 279, Layer Name: mixed9, Layer Type: Concatenate
# Index: 280, Layer Name: conv2d_183, Layer Type: Conv2D
# Index: 281, Layer Name: batch_normalization_183, Layer Type: BatchNormalization
# Index: 282, Layer Name: activation_183, Layer Type: Activation
# Index: 283, Layer Name: conv2d_180, Layer Type: Conv2D
# Index: 284, Layer Name: conv2d_184, Layer Type: Conv2D
# Index: 285, Layer Name: batch_normalization_180, Layer Type: BatchNormalization
# Index: 286, Layer Name: batch_normalization_184, Layer Type: BatchNormalization
# Index: 287, Layer Name: activation_180, Layer Type: Activation
# Index: 288, Layer Name: activation_184, Layer Type: Activation
# Index: 289, Layer Name: conv2d_181, Layer Type: Conv2D
# Index: 290, Layer Name: conv2d_182, Layer Type: Conv2D
# Index: 291, Layer Name: conv2d_185, Layer Type: Conv2D
# Index: 292, Layer Name: conv2d_186, Layer Type: Conv2D
# Index: 293, Layer Name: average_pooling2d_17, Layer Type: AveragePooling2D
# Index: 294, Layer Name: conv2d_179, Layer Type: Conv2D
# Index: 295, Layer Name: batch_normalization_181, Layer Type: BatchNormalization
# Index: 296, Layer Name: batch_normalization_182, Layer Type: BatchNormalization
# Index: 297, Layer Name: batch_normalization_185, Layer Type: BatchNormalization
# Index: 298, Layer Name: batch_normalization_186, Layer Type: BatchNormalization
# Index: 299, Layer Name: conv2d_187, Layer Type: Conv2D
# Index: 300, Layer Name: batch_normalization_179, Layer Type: BatchNormalization
# Index: 301, Layer Name: activation_181, Layer Type: Activation
# Index: 302, Layer Name: activation_182, Layer Type: Activation
# Index: 303, Layer Name: activation_185, Layer Type: Activation
# Index: 304, Layer Name: activation_186, Layer Type: Activation
# Index: 305, Layer Name: batch_normalization_187, Layer Type: BatchNormalization
# Index: 306, Layer Name: activation_179, Layer Type: Activation
# Index: 307, Layer Name: mixed9_1, Layer Type: Concatenate
# Index: 308, Layer Name: concatenate_3, Layer Type: Concatenate
# Index: 309, Layer Name: activation_187, Layer Type: Activation
# Index: 310, Layer Name: mixed10, Layer Type: Concatenate
# Epoch 1/200
# 334/334 [==============================] - ETA: 0s - loss: 4.3593 - accuracy: 0.6749
# Epoch 1: val_accuracy improved from -inf to 0.73150, saving model to InceptionV3.h5
# 334/334 [==============================] - 205s 586ms/step - loss: 4.3593 - accuracy: 0.6749 - val_loss: 2.9725 - val_accuracy: 0.7315 - lr: 0.0010
# Epoch 2/200
# 334/334 [==============================] - ETA: 0s - loss: 1.4582 - accuracy: 0.8488
# Epoch 2: val_accuracy improved from 0.73150 to 0.78325, saving model to InceptionV3.h5
# 334/334 [==============================] - 200s 597ms/step - loss: 1.4582 - accuracy: 0.8488 - val_loss: 2.5069 - val_accuracy: 0.7832 - lr: 0.0010
# Epoch 3/200
# 334/334 [==============================] - ETA: 0s - loss: 0.9721 - accuracy: 0.8975
# Epoch 3: val_accuracy did not improve from 0.78325
# 334/334 [==============================] - 185s 553ms/step - loss: 0.9721 - accuracy: 0.8975 - val_loss: 4.6103 - val_accuracy: 0.7375 - lr: 0.0010
# Epoch 4/200
# 334/334 [==============================] - ETA: 0s - loss: 0.7372 - accuracy: 0.9206
# Epoch 4: val_accuracy did not improve from 0.78325
# 334/334 [==============================] - 181s 541ms/step - loss: 0.7372 - accuracy: 0.9206 - val_loss: 4.5316 - val_accuracy: 0.7508 - lr: 0.0010
# Epoch 5/200
# 334/334 [==============================] - ETA: 0s - loss: 0.5866 - accuracy: 0.9381
# Epoch 5: val_accuracy did not improve from 0.78325
# 334/334 [==============================] - 241s 720ms/step - loss: 0.5866 - accuracy: 0.9381 - val_loss: 5.1120 - val_accuracy: 0.7360 - lr: 0.0010
# Epoch 6/200
# 334/334 [==============================] - ETA: 0s - loss: 0.5595 - accuracy: 0.9426
# Epoch 6: val_accuracy did not improve from 0.78325
# 334/334 [==============================] - 206s 615ms/step - loss: 0.5595 - accuracy: 0.9426 - val_loss: 5.0512 - val_accuracy: 0.7439 - lr: 0.0010
# Epoch 7/200
# 334/334 [==============================] - ETA: 0s - loss: 0.5963 - accuracy: 0.9451
# Epoch 7: val_accuracy did not improve from 0.78325
# 334/334 [==============================] - 197s 589ms/step - loss: 0.5963 - accuracy: 0.9451 - val_loss: 6.5432 - val_accuracy: 0.7408 - lr: 0.0010
# Epoch 8/200
# 334/334 [==============================] - ETA: 0s - loss: 0.5180 - accuracy: 0.9542
# Epoch 8: val_accuracy improved from 0.78325 to 0.80750, saving model to InceptionV3.h5
# 334/334 [==============================] - 197s 590ms/step - loss: 0.5180 - accuracy: 0.9542 - val_loss: 4.4373 - val_accuracy: 0.8075 - lr: 0.0010
# Epoch 9/200
# 334/334 [==============================] - ETA: 0s - loss: 0.5205 - accuracy: 0.9585
# Epoch 9: val_accuracy did not improve from 0.80750
# 334/334 [==============================] - 251s 751ms/step - loss: 0.5205 - accuracy: 0.9585 - val_loss: 6.5655 - val_accuracy: 0.7634 - lr: 0.0010
# Epoch 10/200
# 334/334 [==============================] - ETA: 0s - loss: 0.5336 - accuracy: 0.9593
# Epoch 10: val_accuracy did not improve from 0.80750
# 334/334 [==============================] - 250s 746ms/step - loss: 0.5336 - accuracy: 0.9593 - val_loss: 5.4199 - val_accuracy: 0.8023 - lr: 0.0010
# Epoch 11/200
# 334/334 [==============================] - ETA: 0s - loss: 0.5018 - accuracy: 0.9622
# Epoch 11: val_accuracy did not improve from 0.80750
# 334/334 [==============================] - 250s 747ms/step - loss: 0.5018 - accuracy: 0.9622 - val_loss: 8.0689 - val_accuracy: 0.7517 - lr: 0.0010
# Epoch 12/200
# 334/334 [==============================] - ETA: 0s - loss: 0.3627 - accuracy: 0.9701
# Epoch 12: val_accuracy did not improve from 0.80750
# 334/334 [==============================] - 248s 741ms/step - loss: 0.3627 - accuracy: 0.9701 - val_loss: 6.1104 - val_accuracy: 0.7943 - lr: 0.0010
# Epoch 13/200
# 213/334 [==================>...........] - ETA: 59s - loss: 0.3945 - accuracy: 0.9702
# Epoch 13: val_accuracy did not improve from 0.80750
# 334/334 [==============================] - 250s 746ms/step - loss: 0.4557 - accuracy: 0.9674 - val_loss: 7.6892 - val_accuracy: 0.7836 - lr: 0.0010
# Epoch 14/200
# 334/334 [==============================] - ETA: 0s - loss: 0.4882 - accuracy: 0.9685
# Epoch 14: val_accuracy did not improve from 0.80750
# 334/334 [==============================] - 175s 523ms/step - loss: 0.4882 - accuracy: 0.9685 - val_loss: 7.4165 - val_accuracy: 0.7921 - lr: 0.0010
# Epoch 15/200
# 334/334 [==============================] - ETA: 0s - loss: 0.3680 - accuracy: 0.9751
# Epoch 15: val_accuracy did not improve from 0.80750
# 334/334 [==============================] - 176s 528ms/step - loss: 0.3680 - accuracy: 0.9751 - val_loss: 7.6488 - val_accuracy: 0.7933 - lr: 0.0010
# Epoch 16/200
# 334/334 [==============================] - ETA: 0s - loss: 0.4689 - accuracy: 0.9701
# Epoch 16: val_accuracy did not improve from 0.80750
# 334/334 [==============================] - 183s 547ms/step - loss: 0.4689 - accuracy: 0.9701 - val_loss: 10.4662 - val_accuracy: 0.7565 - lr: 0.0010
# Epoch 17/200
# 334/334 [==============================] - ETA: 0s - loss: 0.4390 - accuracy: 0.9735
# Epoch 17: val_accuracy did not improve from 0.80750
# 334/334 [==============================] - 184s 549ms/step - loss: 0.4390 - accuracy: 0.9735 - val_loss: 7.6966 - val_accuracy: 0.7935 - lr: 0.0010
# Epoch 18/200
# 334/334 [==============================] - ETA: 0s - loss: 0.3711 - accuracy: 0.9767
# Epoch 18: val_accuracy improved from 0.80750 to 0.80838, saving model to InceptionV3.h5
# 334/334 [==============================] - 185s 551ms/step - loss: 0.3711 - accuracy: 0.9767 - val_loss: 7.6009 - val_accuracy: 0.8084 - lr: 0.0010
# Epoch 19/200
# 334/334 [==============================] - ETA: 0s - loss: 0.2890 - accuracy: 0.9803
# Epoch 19: val_accuracy did not improve from 0.80838
# 334/334 [==============================] - 183s 546ms/step - loss: 0.2890 - accuracy: 0.9803 - val_loss: 8.2965 - val_accuracy: 0.8019 - lr: 0.0010
# Epoch 20/200
# 334/334 [==============================] - ETA: 0s - loss: 0.3284 - accuracy: 0.9797
# Epoch 20: val_accuracy did not improve from 0.80838
# 334/334 [==============================] - 178s 533ms/step - loss: 0.3284 - accuracy: 0.9797 - val_loss: 8.7521 - val_accuracy: 0.7979 - lr: 0.0010
# Epoch 21/200
# 334/334 [==============================] - ETA: 0s - loss: 0.3389 - accuracy: 0.9799
# Epoch 21: val_accuracy did not improve from 0.80838
# 334/334 [==============================] - 183s 547ms/step - loss: 0.3389 - accuracy: 0.9799 - val_loss: 9.4459 - val_accuracy: 0.7981 - lr: 0.0010
# Epoch 22/200
# 334/334 [==============================] - ETA: 0s - loss: 0.2860 - accuracy: 0.9822
# Epoch 22: val_accuracy did not improve from 0.80838
# 334/334 [==============================] - 183s 546ms/step - loss: 0.2860 - accuracy: 0.9822 - val_loss: 9.8353 - val_accuracy: 0.7896 - lr: 0.0010
# Epoch 23/200
# 334/334 [==============================] - ETA: 0s - loss: 0.2080 - accuracy: 0.9866
# Epoch 23: val_accuracy did not improve from 0.80838
# 334/334 [==============================] - 183s 546ms/step - loss: 0.2080 - accuracy: 0.9866 - val_loss: 12.4014 - val_accuracy: 0.7720 - lr: 0.0010
# Epoch 24/200
# 334/334 [==============================] - ETA: 0s - loss: 0.3700 - accuracy: 0.9793
# Epoch 24: val_accuracy did not improve from 0.80838
# 334/334 [==============================] - 184s 550ms/step - loss: 0.3700 - accuracy: 0.9793 - val_loss: 10.0538 - val_accuracy: 0.7950 - lr: 0.0010
# Epoch 25/200
# 334/334 [==============================] - ETA: 0s - loss: 0.3265 - accuracy: 0.9818
# Epoch 25: val_accuracy did not improve from 0.80838
# 334/334 [==============================] - 171s 511ms/step - loss: 0.3265 - accuracy: 0.9818 - val_loss: 10.1167 - val_accuracy: 0.7933 - lr: 0.0010
# Epoch 26/200
# 334/334 [==============================] - ETA: 0s - loss: 0.3294 - accuracy: 0.9822
# Epoch 26: val_accuracy did not improve from 0.80838
# 334/334 [==============================] - 184s 551ms/step - loss: 0.3294 - accuracy: 0.9822 - val_loss: 11.6703 - val_accuracy: 0.7876 - lr: 0.0010
# Epoch 27/200
# 334/334 [==============================] - ETA: 0s - loss: 0.2652 - accuracy: 0.9858
# Epoch 27: val_accuracy did not improve from 0.80838
# 334/334 [==============================] - 182s 543ms/step - loss: 0.2652 - accuracy: 0.9858 - val_loss: 12.0513 - val_accuracy: 0.7729 - lr: 0.0010
# Epoch 28/200
# 334/334 [==============================] - ETA: 0s - loss: 0.2659 - accuracy: 0.9860
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Restoring model weights from the end of the best epoch: 18.
#
# Epoch 28: val_accuracy did not improve from 0.80838
# 334/334 [==============================] - 183s 546ms/step - loss: 0.2659 - accuracy: 0.9860 - val_loss: 11.6388 - val_accuracy: 0.7919 - lr: 0.0010
# Epoch 28: early stopping
# Training Time: 95.28 minutes
# 84/84 [==============================] - 37s 408ms/step
# 84/84 [==============================] - 35s 412ms/step - loss: 7.6009 - accuracy: 0.8084
# Final Validation Accuracy: 0.8084
# Final Validation Loss: 7.6009
# 84/84 [==============================] - 34s 403ms/step
# Confusion Matrix:
# [[714  23   0  13   5   0  26   5   1  13]
#  [ 37 527  10  99  35   2  39  32  17   2]
#  [  0   1 752   4   2   2   4  19  15   1]
#  [  8  65   6 647  34   0  24  14   1   1]
#  [  9  36   3  34 672   7  14  12  10   3]
#  [  0  12  28   0  50 664  14   2  26   4]
#  [ 40  43  12  46  37   8 559  25  27   3]
#  [ 26  41  66  25  21   3  35 490  88   5]
#  [  2   9  24  10  10  11   8  69 654   3]
#  [  0   2   0   2   0   0   0   0   8 788]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87       800
#            1       0.69      0.66      0.68       800
#            2       0.83      0.94      0.88       800
#            3       0.74      0.81      0.77       800
#            4       0.78      0.84      0.81       800
#            5       0.95      0.83      0.89       800
#            6       0.77      0.70      0.73       800
#            7       0.73      0.61      0.67       800
#            8       0.77      0.82      0.79       800
#            9       0.96      0.98      0.97       800
#
#     accuracy                           0.81      8000
#    macro avg       0.81      0.81      0.81      8000
# weighted avg       0.81      0.81      0.81      8000
