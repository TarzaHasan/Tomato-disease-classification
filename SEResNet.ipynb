# %%
#SEResNet
import warnings
from sklearn.exceptions import UndefinedMetricWarning
# Suppress specific sklearn warning
warnings.filterwarnings("ignore", category=UndefinedMetricWarning)

import os
import time
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import ResNet101V2
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from sklearn.metrics import roc_curve, auc, confusion_matrix, classification_report

# Dataset and Parameters
dataset_dir ="./Tomato"
img_size = (224, 224)
batch_size = 96
num_classes = 10

# Data Generators
datagen = ImageDataGenerator(rescale=1.0 / 255, validation_split=0.2)
train_generator = datagen.flow_from_directory(
    dataset_dir, target_size=img_size, batch_size=batch_size, class_mode="categorical", subset="training", shuffle=True)
val_generator = datagen.flow_from_directory(
    dataset_dir, target_size=img_size, batch_size=batch_size, class_mode="categorical", subset="validation", shuffle=False)

# Load ResNet50 model without the top layer
base_model = ResNet101V2(include_top=False, weights="imagenet", input_shape=(224, 224, 3))
base_model.trainable = False
for layer in base_model.layers[-5:]:
    layer.trainable = True
# Print ResNet50 layers
for idx, layer in enumerate(base_model.layers):
    print(f"Index: {idx}, Layer Name: {layer.name}, Layer Type: {layer.__class__.__name__}")

# Function for Squeeze-and-Excitation Block (Define it if not already defined)
def squeeze_excite_block(input_tensor, ratio=16):
    """Applies Squeeze-and-Excitation block."""
    filters = input_tensor.shape[-1]
    se = layers.GlobalAveragePooling2D()(input_tensor)
    se = layers.Dense(filters // ratio, activation="relu")(se)
    se = layers.Dense(filters, activation="sigmoid")(se)
    se = layers.Multiply()([input_tensor, se])
    return se

# Add SE Block and custom layers
x = squeeze_excite_block(base_model.output)
x = layers.Flatten()(x)
output = layers.Dense(10, activation="softmax")(x)
# Define model
model = models.Model(inputs=base_model.input, outputs=output)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss="categorical_crossentropy", metrics=["accuracy"])

# Callbacks
reduce_lr = ReduceLROnPlateau(monitor="val_accuracy", factor=0.5, patience=10, verbose=1)
early_stop = EarlyStopping(monitor="val_accuracy", patience=10, restore_best_weights=True, verbose=1)
model_checkpoint = ModelCheckpoint("./best_model_SeResnet.h5", monitor="val_accuracy", save_best_only=True, verbose=1)
callbacks = [reduce_lr, early_stop, model_checkpoint]

# Training
start_time = time.time()
history = model.fit(train_generator, validation_data=val_generator, epochs=200, callbacks=callbacks)
model.save("./SEResnet.h5")
print(f"Training Time: {(time.time() - start_time) / 60:.2f} minutes")

# ROC Curve
y_pred = model.predict(val_generator, verbose=1)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = val_generator.classes
class_names = list(val_generator.class_indices.keys())
y_true_one_hot = to_categorical(y_true, num_classes=len(class_names))

fpr = {}
tpr_stage1 = {}
roc_auc = {}

plt.figure(figsize=(12, 8))
for i in range(len(class_names)):
    fpr[i], tpr_stage1[i], _ = roc_curve(y_true_one_hot[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr_stage1[i])
    plt.plot(fpr[i], tpr_stage1[i], label=f' {class_names[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# Plot Training History
def plot_history(history):
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(history.history["accuracy"], label="Training Accuracy")
    plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
    plt.title("Accuracy")
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(history.history["loss"], label="Training Loss")
    plt.plot(history.history["val_loss"], label="Validation Loss")
    plt.title("Loss")
    plt.legend()
    plt.show()

plot_history(history)

# Evaluate the Final Model
val_loss, val_acc = model.evaluate(val_generator)
print(f"Final Validation Accuracy: {val_acc:.4f}")
print(f"Final Validation Loss: {val_loss:.4f}")

# Confusion Matrix and Report
y_pred = model.predict(val_generator, batch_size=batch_size, verbose=1)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = val_generator.classes

conf_matrix = confusion_matrix(y_true, y_pred_classes)
print("Confusion Matrix:")
print(conf_matrix)

print("Classification Report:")
print(classification_report(y_true, y_pred_classes))

# Plot Confusion Matrix
def plot_confusion_matrix(cm, classes):
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=classes, yticklabels=classes)
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.title("Confusion Matrix")
    plt.show()

class_labels = list(val_generator.class_indices.keys())
plot_confusion_matrix(conf_matrix, class_labels)
# Out:
# Found 32000 images belonging to 10 classes.
# Found 8000 images belonging to 10 classes.
# Index: 0, Layer Name: input_1, Layer Type: InputLayer
# Index: 1, Layer Name: conv1_pad, Layer Type: ZeroPadding2D
# Index: 2, Layer Name: conv1_conv, Layer Type: Conv2D
# Index: 3, Layer Name: pool1_pad, Layer Type: ZeroPadding2D
# Index: 4, Layer Name: pool1_pool, Layer Type: MaxPooling2D
# Index: 5, Layer Name: conv2_block1_preact_bn, Layer Type: BatchNormalization
# Index: 6, Layer Name: conv2_block1_preact_relu, Layer Type: Activation
# Index: 7, Layer Name: conv2_block1_1_conv, Layer Type: Conv2D
# Index: 8, Layer Name: conv2_block1_1_bn, Layer Type: BatchNormalization
# Index: 9, Layer Name: conv2_block1_1_relu, Layer Type: Activation
# Index: 10, Layer Name: conv2_block1_2_pad, Layer Type: ZeroPadding2D
# Index: 11, Layer Name: conv2_block1_2_conv, Layer Type: Conv2D
# Index: 12, Layer Name: conv2_block1_2_bn, Layer Type: BatchNormalization
# Index: 13, Layer Name: conv2_block1_2_relu, Layer Type: Activation
# Index: 14, Layer Name: conv2_block1_0_conv, Layer Type: Conv2D
# Index: 15, Layer Name: conv2_block1_3_conv, Layer Type: Conv2D
# Index: 16, Layer Name: conv2_block1_out, Layer Type: Add
# Index: 17, Layer Name: conv2_block2_preact_bn, Layer Type: BatchNormalization
# Index: 18, Layer Name: conv2_block2_preact_relu, Layer Type: Activation
# Index: 19, Layer Name: conv2_block2_1_conv, Layer Type: Conv2D
# Index: 20, Layer Name: conv2_block2_1_bn, Layer Type: BatchNormalization
# Index: 21, Layer Name: conv2_block2_1_relu, Layer Type: Activation
# Index: 22, Layer Name: conv2_block2_2_pad, Layer Type: ZeroPadding2D
# Index: 23, Layer Name: conv2_block2_2_conv, Layer Type: Conv2D
# Index: 24, Layer Name: conv2_block2_2_bn, Layer Type: BatchNormalization
# Index: 25, Layer Name: conv2_block2_2_relu, Layer Type: Activation
# Index: 26, Layer Name: conv2_block2_3_conv, Layer Type: Conv2D
# Index: 27, Layer Name: conv2_block2_out, Layer Type: Add
# Index: 28, Layer Name: conv2_block3_preact_bn, Layer Type: BatchNormalization
# Index: 29, Layer Name: conv2_block3_preact_relu, Layer Type: Activation
# Index: 30, Layer Name: conv2_block3_1_conv, Layer Type: Conv2D
# Index: 31, Layer Name: conv2_block3_1_bn, Layer Type: BatchNormalization
# Index: 32, Layer Name: conv2_block3_1_relu, Layer Type: Activation
# Index: 33, Layer Name: conv2_block3_2_pad, Layer Type: ZeroPadding2D
# Index: 34, Layer Name: conv2_block3_2_conv, Layer Type: Conv2D
# Index: 35, Layer Name: conv2_block3_2_bn, Layer Type: BatchNormalization
# Index: 36, Layer Name: conv2_block3_2_relu, Layer Type: Activation
# Index: 37, Layer Name: max_pooling2d, Layer Type: MaxPooling2D
# Index: 38, Layer Name: conv2_block3_3_conv, Layer Type: Conv2D
# Index: 39, Layer Name: conv2_block3_out, Layer Type: Add
# Index: 40, Layer Name: conv3_block1_preact_bn, Layer Type: BatchNormalization
# Index: 41, Layer Name: conv3_block1_preact_relu, Layer Type: Activation
# Index: 42, Layer Name: conv3_block1_1_conv, Layer Type: Conv2D
# Index: 43, Layer Name: conv3_block1_1_bn, Layer Type: BatchNormalization
# Index: 44, Layer Name: conv3_block1_1_relu, Layer Type: Activation
# Index: 45, Layer Name: conv3_block1_2_pad, Layer Type: ZeroPadding2D
# Index: 46, Layer Name: conv3_block1_2_conv, Layer Type: Conv2D
# Index: 47, Layer Name: conv3_block1_2_bn, Layer Type: BatchNormalization
# Index: 48, Layer Name: conv3_block1_2_relu, Layer Type: Activation
# Index: 49, Layer Name: conv3_block1_0_conv, Layer Type: Conv2D
# Index: 50, Layer Name: conv3_block1_3_conv, Layer Type: Conv2D
# Index: 51, Layer Name: conv3_block1_out, Layer Type: Add
# Index: 52, Layer Name: conv3_block2_preact_bn, Layer Type: BatchNormalization
# Index: 53, Layer Name: conv3_block2_preact_relu, Layer Type: Activation
# Index: 54, Layer Name: conv3_block2_1_conv, Layer Type: Conv2D
# Index: 55, Layer Name: conv3_block2_1_bn, Layer Type: BatchNormalization
# Index: 56, Layer Name: conv3_block2_1_relu, Layer Type: Activation
# Index: 57, Layer Name: conv3_block2_2_pad, Layer Type: ZeroPadding2D
# Index: 58, Layer Name: conv3_block2_2_conv, Layer Type: Conv2D
# Index: 59, Layer Name: conv3_block2_2_bn, Layer Type: BatchNormalization
# Index: 60, Layer Name: conv3_block2_2_relu, Layer Type: Activation
# Index: 61, Layer Name: conv3_block2_3_conv, Layer Type: Conv2D
# Index: 62, Layer Name: conv3_block2_out, Layer Type: Add
# Index: 63, Layer Name: conv3_block3_preact_bn, Layer Type: BatchNormalization
# Index: 64, Layer Name: conv3_block3_preact_relu, Layer Type: Activation
# Index: 65, Layer Name: conv3_block3_1_conv, Layer Type: Conv2D
# Index: 66, Layer Name: conv3_block3_1_bn, Layer Type: BatchNormalization
# Index: 67, Layer Name: conv3_block3_1_relu, Layer Type: Activation
# Index: 68, Layer Name: conv3_block3_2_pad, Layer Type: ZeroPadding2D
# Index: 69, Layer Name: conv3_block3_2_conv, Layer Type: Conv2D
# Index: 70, Layer Name: conv3_block3_2_bn, Layer Type: BatchNormalization
# Index: 71, Layer Name: conv3_block3_2_relu, Layer Type: Activation
# Index: 72, Layer Name: conv3_block3_3_conv, Layer Type: Conv2D
# Index: 73, Layer Name: conv3_block3_out, Layer Type: Add
# Index: 74, Layer Name: conv3_block4_preact_bn, Layer Type: BatchNormalization
# Index: 75, Layer Name: conv3_block4_preact_relu, Layer Type: Activation
# Index: 76, Layer Name: conv3_block4_1_conv, Layer Type: Conv2D
# Index: 77, Layer Name: conv3_block4_1_bn, Layer Type: BatchNormalization
# Index: 78, Layer Name: conv3_block4_1_relu, Layer Type: Activation
# Index: 79, Layer Name: conv3_block4_2_pad, Layer Type: ZeroPadding2D
# Index: 80, Layer Name: conv3_block4_2_conv, Layer Type: Conv2D
# Index: 81, Layer Name: conv3_block4_2_bn, Layer Type: BatchNormalization
# Index: 82, Layer Name: conv3_block4_2_relu, Layer Type: Activation
# Index: 83, Layer Name: max_pooling2d_1, Layer Type: MaxPooling2D
# Index: 84, Layer Name: conv3_block4_3_conv, Layer Type: Conv2D
# Index: 85, Layer Name: conv3_block4_out, Layer Type: Add
# Index: 86, Layer Name: conv4_block1_preact_bn, Layer Type: BatchNormalization
# Index: 87, Layer Name: conv4_block1_preact_relu, Layer Type: Activation
# Index: 88, Layer Name: conv4_block1_1_conv, Layer Type: Conv2D
# Index: 89, Layer Name: conv4_block1_1_bn, Layer Type: BatchNormalization
# Index: 90, Layer Name: conv4_block1_1_relu, Layer Type: Activation
# Index: 91, Layer Name: conv4_block1_2_pad, Layer Type: ZeroPadding2D
# Index: 92, Layer Name: conv4_block1_2_conv, Layer Type: Conv2D
# Index: 93, Layer Name: conv4_block1_2_bn, Layer Type: BatchNormalization
# Index: 94, Layer Name: conv4_block1_2_relu, Layer Type: Activation
# Index: 95, Layer Name: conv4_block1_0_conv, Layer Type: Conv2D
# Index: 96, Layer Name: conv4_block1_3_conv, Layer Type: Conv2D
# Index: 97, Layer Name: conv4_block1_out, Layer Type: Add
# Index: 98, Layer Name: conv4_block2_preact_bn, Layer Type: BatchNormalization
# Index: 99, Layer Name: conv4_block2_preact_relu, Layer Type: Activation
# Index: 100, Layer Name: conv4_block2_1_conv, Layer Type: Conv2D
# Index: 101, Layer Name: conv4_block2_1_bn, Layer Type: BatchNormalization
# Index: 102, Layer Name: conv4_block2_1_relu, Layer Type: Activation
# Index: 103, Layer Name: conv4_block2_2_pad, Layer Type: ZeroPadding2D
# Index: 104, Layer Name: conv4_block2_2_conv, Layer Type: Conv2D
# Index: 105, Layer Name: conv4_block2_2_bn, Layer Type: BatchNormalization
# Index: 106, Layer Name: conv4_block2_2_relu, Layer Type: Activation
# Index: 107, Layer Name: conv4_block2_3_conv, Layer Type: Conv2D
# Index: 108, Layer Name: conv4_block2_out, Layer Type: Add
# Index: 109, Layer Name: conv4_block3_preact_bn, Layer Type: BatchNormalization
# Index: 110, Layer Name: conv4_block3_preact_relu, Layer Type: Activation
# Index: 111, Layer Name: conv4_block3_1_conv, Layer Type: Conv2D
# Index: 112, Layer Name: conv4_block3_1_bn, Layer Type: BatchNormalization
# Index: 113, Layer Name: conv4_block3_1_relu, Layer Type: Activation
# Index: 114, Layer Name: conv4_block3_2_pad, Layer Type: ZeroPadding2D
# Index: 115, Layer Name: conv4_block3_2_conv, Layer Type: Conv2D
# Index: 116, Layer Name: conv4_block3_2_bn, Layer Type: BatchNormalization
# Index: 117, Layer Name: conv4_block3_2_relu, Layer Type: Activation
# Index: 118, Layer Name: conv4_block3_3_conv, Layer Type: Conv2D
# Index: 119, Layer Name: conv4_block3_out, Layer Type: Add
# Index: 120, Layer Name: conv4_block4_preact_bn, Layer Type: BatchNormalization
# Index: 121, Layer Name: conv4_block4_preact_relu, Layer Type: Activation
# Index: 122, Layer Name: conv4_block4_1_conv, Layer Type: Conv2D
# Index: 123, Layer Name: conv4_block4_1_bn, Layer Type: BatchNormalization
# Index: 124, Layer Name: conv4_block4_1_relu, Layer Type: Activation
# Index: 125, Layer Name: conv4_block4_2_pad, Layer Type: ZeroPadding2D
# Index: 126, Layer Name: conv4_block4_2_conv, Layer Type: Conv2D
# Index: 127, Layer Name: conv4_block4_2_bn, Layer Type: BatchNormalization
# Index: 128, Layer Name: conv4_block4_2_relu, Layer Type: Activation
# Index: 129, Layer Name: conv4_block4_3_conv, Layer Type: Conv2D
# Index: 130, Layer Name: conv4_block4_out, Layer Type: Add
# Index: 131, Layer Name: conv4_block5_preact_bn, Layer Type: BatchNormalization
# Index: 132, Layer Name: conv4_block5_preact_relu, Layer Type: Activation
# Index: 133, Layer Name: conv4_block5_1_conv, Layer Type: Conv2D
# Index: 134, Layer Name: conv4_block5_1_bn, Layer Type: BatchNormalization
# Index: 135, Layer Name: conv4_block5_1_relu, Layer Type: Activation
# Index: 136, Layer Name: conv4_block5_2_pad, Layer Type: ZeroPadding2D
# Index: 137, Layer Name: conv4_block5_2_conv, Layer Type: Conv2D
# Index: 138, Layer Name: conv4_block5_2_bn, Layer Type: BatchNormalization
# Index: 139, Layer Name: conv4_block5_2_relu, Layer Type: Activation
# Index: 140, Layer Name: conv4_block5_3_conv, Layer Type: Conv2D
# Index: 141, Layer Name: conv4_block5_out, Layer Type: Add
# Index: 142, Layer Name: conv4_block6_preact_bn, Layer Type: BatchNormalization
# Index: 143, Layer Name: conv4_block6_preact_relu, Layer Type: Activation
# Index: 144, Layer Name: conv4_block6_1_conv, Layer Type: Conv2D
# Index: 145, Layer Name: conv4_block6_1_bn, Layer Type: BatchNormalization
# Index: 146, Layer Name: conv4_block6_1_relu, Layer Type: Activation
# Index: 147, Layer Name: conv4_block6_2_pad, Layer Type: ZeroPadding2D
# Index: 148, Layer Name: conv4_block6_2_conv, Layer Type: Conv2D
# Index: 149, Layer Name: conv4_block6_2_bn, Layer Type: BatchNormalization
# Index: 150, Layer Name: conv4_block6_2_relu, Layer Type: Activation
# Index: 151, Layer Name: conv4_block6_3_conv, Layer Type: Conv2D
# Index: 152, Layer Name: conv4_block6_out, Layer Type: Add
# Index: 153, Layer Name: conv4_block7_preact_bn, Layer Type: BatchNormalization
# Index: 154, Layer Name: conv4_block7_preact_relu, Layer Type: Activation
# Index: 155, Layer Name: conv4_block7_1_conv, Layer Type: Conv2D
# Index: 156, Layer Name: conv4_block7_1_bn, Layer Type: BatchNormalization
# Index: 157, Layer Name: conv4_block7_1_relu, Layer Type: Activation
# Index: 158, Layer Name: conv4_block7_2_pad, Layer Type: ZeroPadding2D
# Index: 159, Layer Name: conv4_block7_2_conv, Layer Type: Conv2D
# Index: 160, Layer Name: conv4_block7_2_bn, Layer Type: BatchNormalization
# Index: 161, Layer Name: conv4_block7_2_relu, Layer Type: Activation
# Index: 162, Layer Name: conv4_block7_3_conv, Layer Type: Conv2D
# Index: 163, Layer Name: conv4_block7_out, Layer Type: Add
# Index: 164, Layer Name: conv4_block8_preact_bn, Layer Type: BatchNormalization
# Index: 165, Layer Name: conv4_block8_preact_relu, Layer Type: Activation
# Index: 166, Layer Name: conv4_block8_1_conv, Layer Type: Conv2D
# Index: 167, Layer Name: conv4_block8_1_bn, Layer Type: BatchNormalization
# Index: 168, Layer Name: conv4_block8_1_relu, Layer Type: Activation
# Index: 169, Layer Name: conv4_block8_2_pad, Layer Type: ZeroPadding2D
# Index: 170, Layer Name: conv4_block8_2_conv, Layer Type: Conv2D
# Index: 171, Layer Name: conv4_block8_2_bn, Layer Type: BatchNormalization
# Index: 172, Layer Name: conv4_block8_2_relu, Layer Type: Activation
# Index: 173, Layer Name: conv4_block8_3_conv, Layer Type: Conv2D
# Index: 174, Layer Name: conv4_block8_out, Layer Type: Add
# Index: 175, Layer Name: conv4_block9_preact_bn, Layer Type: BatchNormalization
# Index: 176, Layer Name: conv4_block9_preact_relu, Layer Type: Activation
# Index: 177, Layer Name: conv4_block9_1_conv, Layer Type: Conv2D
# Index: 178, Layer Name: conv4_block9_1_bn, Layer Type: BatchNormalization
# Index: 179, Layer Name: conv4_block9_1_relu, Layer Type: Activation
# Index: 180, Layer Name: conv4_block9_2_pad, Layer Type: ZeroPadding2D
# Index: 181, Layer Name: conv4_block9_2_conv, Layer Type: Conv2D
# Index: 182, Layer Name: conv4_block9_2_bn, Layer Type: BatchNormalization
# Index: 183, Layer Name: conv4_block9_2_relu, Layer Type: Activation
# Index: 184, Layer Name: conv4_block9_3_conv, Layer Type: Conv2D
# Index: 185, Layer Name: conv4_block9_out, Layer Type: Add
# Index: 186, Layer Name: conv4_block10_preact_bn, Layer Type: BatchNormalization
# Index: 187, Layer Name: conv4_block10_preact_relu, Layer Type: Activation
# Index: 188, Layer Name: conv4_block10_1_conv, Layer Type: Conv2D
# Index: 189, Layer Name: conv4_block10_1_bn, Layer Type: BatchNormalization
# Index: 190, Layer Name: conv4_block10_1_relu, Layer Type: Activation
# Index: 191, Layer Name: conv4_block10_2_pad, Layer Type: ZeroPadding2D
# Index: 192, Layer Name: conv4_block10_2_conv, Layer Type: Conv2D
# Index: 193, Layer Name: conv4_block10_2_bn, Layer Type: BatchNormalization
# Index: 194, Layer Name: conv4_block10_2_relu, Layer Type: Activation
# Index: 195, Layer Name: conv4_block10_3_conv, Layer Type: Conv2D
# Index: 196, Layer Name: conv4_block10_out, Layer Type: Add
# Index: 197, Layer Name: conv4_block11_preact_bn, Layer Type: BatchNormalization
# Index: 198, Layer Name: conv4_block11_preact_relu, Layer Type: Activation
# Index: 199, Layer Name: conv4_block11_1_conv, Layer Type: Conv2D
# Index: 200, Layer Name: conv4_block11_1_bn, Layer Type: BatchNormalization
# Index: 201, Layer Name: conv4_block11_1_relu, Layer Type: Activation
# Index: 202, Layer Name: conv4_block11_2_pad, Layer Type: ZeroPadding2D
# Index: 203, Layer Name: conv4_block11_2_conv, Layer Type: Conv2D
# Index: 204, Layer Name: conv4_block11_2_bn, Layer Type: BatchNormalization
# Index: 205, Layer Name: conv4_block11_2_relu, Layer Type: Activation
# Index: 206, Layer Name: conv4_block11_3_conv, Layer Type: Conv2D
# Index: 207, Layer Name: conv4_block11_out, Layer Type: Add
# Index: 208, Layer Name: conv4_block12_preact_bn, Layer Type: BatchNormalization
# Index: 209, Layer Name: conv4_block12_preact_relu, Layer Type: Activation
# Index: 210, Layer Name: conv4_block12_1_conv, Layer Type: Conv2D
# Index: 211, Layer Name: conv4_block12_1_bn, Layer Type: BatchNormalization
# Index: 212, Layer Name: conv4_block12_1_relu, Layer Type: Activation
# Index: 213, Layer Name: conv4_block12_2_pad, Layer Type: ZeroPadding2D
# Index: 214, Layer Name: conv4_block12_2_conv, Layer Type: Conv2D
# Index: 215, Layer Name: conv4_block12_2_bn, Layer Type: BatchNormalization
# Index: 216, Layer Name: conv4_block12_2_relu, Layer Type: Activation
# Index: 217, Layer Name: conv4_block12_3_conv, Layer Type: Conv2D
# Index: 218, Layer Name: conv4_block12_out, Layer Type: Add
# Index: 219, Layer Name: conv4_block13_preact_bn, Layer Type: BatchNormalization
# Index: 220, Layer Name: conv4_block13_preact_relu, Layer Type: Activation
# Index: 221, Layer Name: conv4_block13_1_conv, Layer Type: Conv2D
# Index: 222, Layer Name: conv4_block13_1_bn, Layer Type: BatchNormalization
# Index: 223, Layer Name: conv4_block13_1_relu, Layer Type: Activation
# Index: 224, Layer Name: conv4_block13_2_pad, Layer Type: ZeroPadding2D
# Index: 225, Layer Name: conv4_block13_2_conv, Layer Type: Conv2D
# Index: 226, Layer Name: conv4_block13_2_bn, Layer Type: BatchNormalization
# Index: 227, Layer Name: conv4_block13_2_relu, Layer Type: Activation
# Index: 228, Layer Name: conv4_block13_3_conv, Layer Type: Conv2D
# Index: 229, Layer Name: conv4_block13_out, Layer Type: Add
# Index: 230, Layer Name: conv4_block14_preact_bn, Layer Type: BatchNormalization
# Index: 231, Layer Name: conv4_block14_preact_relu, Layer Type: Activation
# Index: 232, Layer Name: conv4_block14_1_conv, Layer Type: Conv2D
# Index: 233, Layer Name: conv4_block14_1_bn, Layer Type: BatchNormalization
# Index: 234, Layer Name: conv4_block14_1_relu, Layer Type: Activation
# Index: 235, Layer Name: conv4_block14_2_pad, Layer Type: ZeroPadding2D
# Index: 236, Layer Name: conv4_block14_2_conv, Layer Type: Conv2D
# Index: 237, Layer Name: conv4_block14_2_bn, Layer Type: BatchNormalization
# Index: 238, Layer Name: conv4_block14_2_relu, Layer Type: Activation
# Index: 239, Layer Name: conv4_block14_3_conv, Layer Type: Conv2D
# Index: 240, Layer Name: conv4_block14_out, Layer Type: Add
# Index: 241, Layer Name: conv4_block15_preact_bn, Layer Type: BatchNormalization
# Index: 242, Layer Name: conv4_block15_preact_relu, Layer Type: Activation
# Index: 243, Layer Name: conv4_block15_1_conv, Layer Type: Conv2D
# Index: 244, Layer Name: conv4_block15_1_bn, Layer Type: BatchNormalization
# Index: 245, Layer Name: conv4_block15_1_relu, Layer Type: Activation
# Index: 246, Layer Name: conv4_block15_2_pad, Layer Type: ZeroPadding2D
# Index: 247, Layer Name: conv4_block15_2_conv, Layer Type: Conv2D
# Index: 248, Layer Name: conv4_block15_2_bn, Layer Type: BatchNormalization
# Index: 249, Layer Name: conv4_block15_2_relu, Layer Type: Activation
# Index: 250, Layer Name: conv4_block15_3_conv, Layer Type: Conv2D
# Index: 251, Layer Name: conv4_block15_out, Layer Type: Add
# Index: 252, Layer Name: conv4_block16_preact_bn, Layer Type: BatchNormalization
# Index: 253, Layer Name: conv4_block16_preact_relu, Layer Type: Activation
# Index: 254, Layer Name: conv4_block16_1_conv, Layer Type: Conv2D
# Index: 255, Layer Name: conv4_block16_1_bn, Layer Type: BatchNormalization
# Index: 256, Layer Name: conv4_block16_1_relu, Layer Type: Activation
# Index: 257, Layer Name: conv4_block16_2_pad, Layer Type: ZeroPadding2D
# Index: 258, Layer Name: conv4_block16_2_conv, Layer Type: Conv2D
# Index: 259, Layer Name: conv4_block16_2_bn, Layer Type: BatchNormalization
# Index: 260, Layer Name: conv4_block16_2_relu, Layer Type: Activation
# Index: 261, Layer Name: conv4_block16_3_conv, Layer Type: Conv2D
# Index: 262, Layer Name: conv4_block16_out, Layer Type: Add
# Index: 263, Layer Name: conv4_block17_preact_bn, Layer Type: BatchNormalization
# Index: 264, Layer Name: conv4_block17_preact_relu, Layer Type: Activation
# Index: 265, Layer Name: conv4_block17_1_conv, Layer Type: Conv2D
# Index: 266, Layer Name: conv4_block17_1_bn, Layer Type: BatchNormalization
# Index: 267, Layer Name: conv4_block17_1_relu, Layer Type: Activation
# Index: 268, Layer Name: conv4_block17_2_pad, Layer Type: ZeroPadding2D
# Index: 269, Layer Name: conv4_block17_2_conv, Layer Type: Conv2D
# Index: 270, Layer Name: conv4_block17_2_bn, Layer Type: BatchNormalization
# Index: 271, Layer Name: conv4_block17_2_relu, Layer Type: Activation
# Index: 272, Layer Name: conv4_block17_3_conv, Layer Type: Conv2D
# Index: 273, Layer Name: conv4_block17_out, Layer Type: Add
# Index: 274, Layer Name: conv4_block18_preact_bn, Layer Type: BatchNormalization
# Index: 275, Layer Name: conv4_block18_preact_relu, Layer Type: Activation
# Index: 276, Layer Name: conv4_block18_1_conv, Layer Type: Conv2D
# Index: 277, Layer Name: conv4_block18_1_bn, Layer Type: BatchNormalization
# Index: 278, Layer Name: conv4_block18_1_relu, Layer Type: Activation
# Index: 279, Layer Name: conv4_block18_2_pad, Layer Type: ZeroPadding2D
# Index: 280, Layer Name: conv4_block18_2_conv, Layer Type: Conv2D
# Index: 281, Layer Name: conv4_block18_2_bn, Layer Type: BatchNormalization
# Index: 282, Layer Name: conv4_block18_2_relu, Layer Type: Activation
# Index: 283, Layer Name: conv4_block18_3_conv, Layer Type: Conv2D
# Index: 284, Layer Name: conv4_block18_out, Layer Type: Add
# Index: 285, Layer Name: conv4_block19_preact_bn, Layer Type: BatchNormalization
# Index: 286, Layer Name: conv4_block19_preact_relu, Layer Type: Activation
# Index: 287, Layer Name: conv4_block19_1_conv, Layer Type: Conv2D
# Index: 288, Layer Name: conv4_block19_1_bn, Layer Type: BatchNormalization
# Index: 289, Layer Name: conv4_block19_1_relu, Layer Type: Activation
# Index: 290, Layer Name: conv4_block19_2_pad, Layer Type: ZeroPadding2D
# Index: 291, Layer Name: conv4_block19_2_conv, Layer Type: Conv2D
# Index: 292, Layer Name: conv4_block19_2_bn, Layer Type: BatchNormalization
# Index: 293, Layer Name: conv4_block19_2_relu, Layer Type: Activation
# Index: 294, Layer Name: conv4_block19_3_conv, Layer Type: Conv2D
# Index: 295, Layer Name: conv4_block19_out, Layer Type: Add
# Index: 296, Layer Name: conv4_block20_preact_bn, Layer Type: BatchNormalization
# Index: 297, Layer Name: conv4_block20_preact_relu, Layer Type: Activation
# Index: 298, Layer Name: conv4_block20_1_conv, Layer Type: Conv2D
# Index: 299, Layer Name: conv4_block20_1_bn, Layer Type: BatchNormalization
# Index: 300, Layer Name: conv4_block20_1_relu, Layer Type: Activation
# Index: 301, Layer Name: conv4_block20_2_pad, Layer Type: ZeroPadding2D
# Index: 302, Layer Name: conv4_block20_2_conv, Layer Type: Conv2D
# Index: 303, Layer Name: conv4_block20_2_bn, Layer Type: BatchNormalization
# Index: 304, Layer Name: conv4_block20_2_relu, Layer Type: Activation
# Index: 305, Layer Name: conv4_block20_3_conv, Layer Type: Conv2D
# Index: 306, Layer Name: conv4_block20_out, Layer Type: Add
# Index: 307, Layer Name: conv4_block21_preact_bn, Layer Type: BatchNormalization
# Index: 308, Layer Name: conv4_block21_preact_relu, Layer Type: Activation
# Index: 309, Layer Name: conv4_block21_1_conv, Layer Type: Conv2D
# Index: 310, Layer Name: conv4_block21_1_bn, Layer Type: BatchNormalization
# Index: 311, Layer Name: conv4_block21_1_relu, Layer Type: Activation
# Index: 312, Layer Name: conv4_block21_2_pad, Layer Type: ZeroPadding2D
# Index: 313, Layer Name: conv4_block21_2_conv, Layer Type: Conv2D
# Index: 314, Layer Name: conv4_block21_2_bn, Layer Type: BatchNormalization
# Index: 315, Layer Name: conv4_block21_2_relu, Layer Type: Activation
# Index: 316, Layer Name: conv4_block21_3_conv, Layer Type: Conv2D
# Index: 317, Layer Name: conv4_block21_out, Layer Type: Add
# Index: 318, Layer Name: conv4_block22_preact_bn, Layer Type: BatchNormalization
# Index: 319, Layer Name: conv4_block22_preact_relu, Layer Type: Activation
# Index: 320, Layer Name: conv4_block22_1_conv, Layer Type: Conv2D
# Index: 321, Layer Name: conv4_block22_1_bn, Layer Type: BatchNormalization
# Index: 322, Layer Name: conv4_block22_1_relu, Layer Type: Activation
# Index: 323, Layer Name: conv4_block22_2_pad, Layer Type: ZeroPadding2D
# Index: 324, Layer Name: conv4_block22_2_conv, Layer Type: Conv2D
# Index: 325, Layer Name: conv4_block22_2_bn, Layer Type: BatchNormalization
# Index: 326, Layer Name: conv4_block22_2_relu, Layer Type: Activation
# Index: 327, Layer Name: conv4_block22_3_conv, Layer Type: Conv2D
# Index: 328, Layer Name: conv4_block22_out, Layer Type: Add
# Index: 329, Layer Name: conv4_block23_preact_bn, Layer Type: BatchNormalization
# Index: 330, Layer Name: conv4_block23_preact_relu, Layer Type: Activation
# Index: 331, Layer Name: conv4_block23_1_conv, Layer Type: Conv2D
# Index: 332, Layer Name: conv4_block23_1_bn, Layer Type: BatchNormalization
# Index: 333, Layer Name: conv4_block23_1_relu, Layer Type: Activation
# Index: 334, Layer Name: conv4_block23_2_pad, Layer Type: ZeroPadding2D
# Index: 335, Layer Name: conv4_block23_2_conv, Layer Type: Conv2D
# Index: 336, Layer Name: conv4_block23_2_bn, Layer Type: BatchNormalization
# Index: 337, Layer Name: conv4_block23_2_relu, Layer Type: Activation
# Index: 338, Layer Name: max_pooling2d_2, Layer Type: MaxPooling2D
# Index: 339, Layer Name: conv4_block23_3_conv, Layer Type: Conv2D
# Index: 340, Layer Name: conv4_block23_out, Layer Type: Add
# Index: 341, Layer Name: conv5_block1_preact_bn, Layer Type: BatchNormalization
# Index: 342, Layer Name: conv5_block1_preact_relu, Layer Type: Activation
# Index: 343, Layer Name: conv5_block1_1_conv, Layer Type: Conv2D
# Index: 344, Layer Name: conv5_block1_1_bn, Layer Type: BatchNormalization
# Index: 345, Layer Name: conv5_block1_1_relu, Layer Type: Activation
# Index: 346, Layer Name: conv5_block1_2_pad, Layer Type: ZeroPadding2D
# Index: 347, Layer Name: conv5_block1_2_conv, Layer Type: Conv2D
# Index: 348, Layer Name: conv5_block1_2_bn, Layer Type: BatchNormalization
# Index: 349, Layer Name: conv5_block1_2_relu, Layer Type: Activation
# Index: 350, Layer Name: conv5_block1_0_conv, Layer Type: Conv2D
# Index: 351, Layer Name: conv5_block1_3_conv, Layer Type: Conv2D
# Index: 352, Layer Name: conv5_block1_out, Layer Type: Add
# Index: 353, Layer Name: conv5_block2_preact_bn, Layer Type: BatchNormalization
# Index: 354, Layer Name: conv5_block2_preact_relu, Layer Type: Activation
# Index: 355, Layer Name: conv5_block2_1_conv, Layer Type: Conv2D
# Index: 356, Layer Name: conv5_block2_1_bn, Layer Type: BatchNormalization
# Index: 357, Layer Name: conv5_block2_1_relu, Layer Type: Activation
# Index: 358, Layer Name: conv5_block2_2_pad, Layer Type: ZeroPadding2D
# Index: 359, Layer Name: conv5_block2_2_conv, Layer Type: Conv2D
# Index: 360, Layer Name: conv5_block2_2_bn, Layer Type: BatchNormalization
# Index: 361, Layer Name: conv5_block2_2_relu, Layer Type: Activation
# Index: 362, Layer Name: conv5_block2_3_conv, Layer Type: Conv2D
# Index: 363, Layer Name: conv5_block2_out, Layer Type: Add
# Index: 364, Layer Name: conv5_block3_preact_bn, Layer Type: BatchNormalization
# Index: 365, Layer Name: conv5_block3_preact_relu, Layer Type: Activation
# Index: 366, Layer Name: conv5_block3_1_conv, Layer Type: Conv2D
# Index: 367, Layer Name: conv5_block3_1_bn, Layer Type: BatchNormalization
# Index: 368, Layer Name: conv5_block3_1_relu, Layer Type: Activation
# Index: 369, Layer Name: conv5_block3_2_pad, Layer Type: ZeroPadding2D
# Index: 370, Layer Name: conv5_block3_2_conv, Layer Type: Conv2D
# Index: 371, Layer Name: conv5_block3_2_bn, Layer Type: BatchNormalization
# Index: 372, Layer Name: conv5_block3_2_relu, Layer Type: Activation
# Index: 373, Layer Name: conv5_block3_3_conv, Layer Type: Conv2D
# Index: 374, Layer Name: conv5_block3_out, Layer Type: Add
# Index: 375, Layer Name: post_bn, Layer Type: BatchNormalization
# Index: 376, Layer Name: post_relu, Layer Type: Activation
# Epoch 1/200
# 334/334 [==============================] - ETA: 0s - loss: 0.6648 - accuracy: 0.7882
# Epoch 1: val_accuracy improved from -inf to 0.72787, saving model to King Saaud Tomato\best_model_SeResnet.h5
# 334/334 [==============================] - 569s 2s/step - loss: 0.6648 - accuracy: 0.7882 - val_loss: 0.8252 - val_accuracy: 0.7279 - lr: 0.0010
# Epoch 2/200
# 334/334 [==============================] - ETA: 0s - loss: 0.1778 - accuracy: 0.9402
# Epoch 2: val_accuracy did not improve from 0.72787
# 334/334 [==============================] - 148s 441ms/step - loss: 0.1778 - accuracy: 0.9402 - val_loss: 1.2363 - val_accuracy: 0.7028 - lr: 0.0010
# Epoch 3/200
# 334/334 [==============================] - ETA: 0s - loss: 0.1214 - accuracy: 0.9585
# Epoch 3: val_accuracy did not improve from 0.72787
# 334/334 [==============================] - 145s 432ms/step - loss: 0.1214 - accuracy: 0.9585 - val_loss: 1.3152 - val_accuracy: 0.7143 - lr: 0.0010
# Epoch 4/200
# 334/334 [==============================] - ETA: 0s - loss: 0.0904 - accuracy: 0.9703
# Epoch 4: val_accuracy improved from 0.72787 to 0.77325, saving model to King Saaud Tomato\best_model_SeResnet.h5
# 334/334 [==============================] - 144s 428ms/step - loss: 0.0904 - accuracy: 0.9703 - val_loss: 1.2560 - val_accuracy: 0.7732 - lr: 0.0010
# Epoch 5/200
# 334/334 [==============================] - ETA: 0s - loss: 0.0847 - accuracy: 0.9723
# Epoch 5: val_accuracy did not improve from 0.77325
# 334/334 [==============================] - 139s 415ms/step - loss: 0.0847 - accuracy: 0.9723 - val_loss: 1.6227 - val_accuracy: 0.7410 - lr: 0.0010
# Epoch 6/200
# 334/334 [==============================] - ETA: 0s - loss: 0.0737 - accuracy: 0.9758
# Epoch 6: val_accuracy improved from 0.77325 to 0.77575, saving model to King Saaud Tomato\best_model_SeResnet.h5
# 334/334 [==============================] - 186s 556ms/step - loss: 0.0737 - accuracy: 0.9758 - val_loss: 1.1510 - val_accuracy: 0.7757 - lr: 0.0010
# Epoch 7/200
# 334/334 [==============================] - ETA: 0s - loss: 0.0649 - accuracy: 0.9798
# Epoch 7: val_accuracy did not improve from 0.77575
# 334/334 [==============================] - 185s 552ms/step - loss: 0.0649 - accuracy: 0.9798 - val_loss: 1.3188 - val_accuracy: 0.7688 - lr: 0.0010
# Epoch 8/200
# 334/334 [==============================] - ETA: 0s - loss: 0.0602 - accuracy: 0.9807
# Epoch 8: val_accuracy did not improve from 0.77575
# 334/334 [==============================] - 188s 562ms/step - loss: 0.0602 - accuracy: 0.9807 - val_loss: 1.3306 - val_accuracy: 0.7688 - lr: 0.0010
# Epoch 9/200
# 334/334 [==============================] - ETA: 0s - loss: 0.0548 - accuracy: 0.9822
# Epoch 9: val_accuracy improved from 0.77575 to 0.78175, saving model to King Saaud Tomato\best_model_SeResnet.h5
# 334/334 [==============================] - 201s 601ms/step - loss: 0.0548 - accuracy: 0.9822 - val_loss: 1.4088 - val_accuracy: 0.7818 - lr: 0.0010
# Epoch 10/200
# 334/334 [==============================] - ETA: 0s - loss: 0.0527 - accuracy: 0.9833
# Epoch 10: val_accuracy did not improve from 0.78175
# 334/334 [==============================] - 173s 516ms/step - loss: 0.0527 - accuracy: 0.9833 - val_loss: 2.0613 - val_accuracy: 0.7346 - lr: 0.0010
# Epoch 11/200
# 334/334 [==============================] - ETA: 0s - loss: 0.0592 - accuracy: 0.9812
# Epoch 11: val_accuracy did not improve from 0.78175
# 334/334 [==============================] - 139s 417ms/step - loss: 0.0592 - accuracy: 0.9812 - val_loss: 1.8170 - val_accuracy: 0.7610 - lr: 0.0010
# Epoch 12/200
# 334/334 [==============================] - ETA: 0s - loss: 0.0464 - accuracy: 0.9865
# Epoch 12: val_accuracy did not improve from 0.78175
# 334/334 [==============================] - 108s 322ms/step - loss: 0.0464 - accuracy: 0.9865 - val_loss: 2.3890 - val_accuracy: 0.7324 - lr: 0.0010
# Epoch 13/200
# 334/334 [==============================] - ETA: 0s - loss: 0.0399 - accuracy: 0.9876
# Epoch 13: val_accuracy improved from 0.78175 to 0.79700, saving model to King Saaud Tomato\best_model_SeResnet.h5
# 334/334 [==============================] - 129s 387ms/step - loss: 0.0399 - accuracy: 0.9876 - val_loss: 1.5059 - val_accuracy: 0.7970 - lr: 0.0010
# Epoch 14/200
# 334/334 [==============================] - ETA: 0s - loss: 0.0445 - accuracy: 0.9870
# Epoch 14: val_accuracy did not improve from 0.79700
# 334/334 [==============================] - 110s 328ms/step - loss: 0.0445 - accuracy: 0.9870 - val_loss: 1.8727 - val_accuracy: 0.7714 - lr: 0.0010
# Epoch 15/200
# 334/334 [==============================] - ETA: 0s - loss: 0.0496 - accuracy: 0.9851
# Epoch 15: val_accuracy did not improve from 0.79700
# 334/334 [==============================] - 115s 343ms/step - loss: 0.0496 - accuracy: 0.9851 - val_loss: 1.4393 - val_accuracy: 0.7925 - lr: 0.0010
# Epoch 16/200
# 334/334 [==============================] - ETA: 0s - loss: 0.0279 - accuracy: 0.9914
# Epoch 16: val_accuracy did not improve from 0.79700
# 334/334 [==============================] - 138s 414ms/step - loss: 0.0279 - accuracy: 0.9914 - val_loss: 1.8217 - val_accuracy: 0.7885 - lr: 0.0010
# Epoch 17/200
# 334/334 [==============================] - ETA: 0s - loss: 0.0327 - accuracy: 0.9902
# Epoch 17: val_accuracy did not improve from 0.79700
# 334/334 [==============================] - 140s 419ms/step - loss: 0.0327 - accuracy: 0.9902 - val_loss: 1.8491 - val_accuracy: 0.7797 - lr: 0.0010
# Epoch 18/200
# 334/334 [==============================] - ETA: 0s - loss: 0.0552 - accuracy: 0.9851
# Epoch 18: val_accuracy did not improve from 0.79700
# 334/334 [==============================] - 139s 416ms/step - loss: 0.0552 - accuracy: 0.9851 - val_loss: 2.1121 - val_accuracy: 0.7765 - lr: 0.0010
# Epoch 19/200
# 334/334 [==============================] - ETA: 0s - loss: 0.0360 - accuracy: 0.9894
# Epoch 19: val_accuracy did not improve from 0.79700
# 334/334 [==============================] - 141s 420ms/step - loss: 0.0360 - accuracy: 0.9894 - val_loss: 1.9219 - val_accuracy: 0.7704 - lr: 0.0010
# Epoch 20/200
# 334/334 [==============================] - ETA: 0s - loss: 0.0316 - accuracy: 0.9906
# Epoch 20: val_accuracy did not improve from 0.79700
# 334/334 [==============================] - 139s 414ms/step - loss: 0.0316 - accuracy: 0.9906 - val_loss: 1.6854 - val_accuracy: 0.7959 - lr: 0.0010
# Epoch 21/200
# 334/334 [==============================] - ETA: 0s - loss: 0.0294 - accuracy: 0.9913
# Epoch 21: val_accuracy did not improve from 0.79700
# 334/334 [==============================] - 140s 417ms/step - loss: 0.0294 - accuracy: 0.9913 - val_loss: 2.0482 - val_accuracy: 0.7765 - lr: 0.0010
# Epoch 22/200
# 334/334 [==============================] - ETA: 0s - loss: 0.0358 - accuracy: 0.9896
# Epoch 22: val_accuracy did not improve from 0.79700
# 334/334 [==============================] - 128s 380ms/step - loss: 0.0358 - accuracy: 0.9896 - val_loss: 2.1155 - val_accuracy: 0.7754 - lr: 0.0010
# Epoch 23/200
# 334/334 [==============================] - ETA: 0s - loss: 0.0348 - accuracy: 0.9909
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Restoring model weights from the end of the best epoch: 13.
#
# Epoch 23: val_accuracy did not improve from 0.79700
# 334/334 [==============================] - 110s 326ms/step - loss: 0.0348 - accuracy: 0.9909 - val_loss: 1.7737 - val_accuracy: 0.7935 - lr: 0.0010
# Epoch 23: early stopping
# Training Time: 64.91 minutes
# 84/84 [==============================] - 25s 258ms/step
# 84/84 [==============================] - 22s 251ms/step - loss: 1.5059 - accuracy: 0.7970
# Final Validation Accuracy: 0.7970
# Final Validation Loss: 1.5059
# 84/84 [==============================] - 22s 256ms/step
# Confusion Matrix:
# [[728  15   0  13   0   0  34   2   2   6]
#  [ 22 532   7  97  19   1  82  25  10   5]
#  [  0   3 722   9   1   6  15  31  11   2]
#  [  7  50   7 629  20   0  73   8   2   4]
#  [ 10  59   0  46 540  21  91  10  15   8]
#  [  0   2   4   2  38 708  34   2   4   6]
#  [ 28  36   3  29   9   1 677  14   3   0]
#  [ 16  52  43  59  11   4  77 471  57  10]
#  [  0   9  20  23  12  15  55  61 601   4]
#  [  4   4   2   4   2   4   6   2   4 768]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.91      0.90       800
#            1       0.70      0.67      0.68       800
#            2       0.89      0.90      0.90       800
#            3       0.69      0.79      0.74       800
#            4       0.83      0.68      0.74       800
#            5       0.93      0.89      0.91       800
#            6       0.59      0.85      0.70       800
#            7       0.75      0.59      0.66       800
#            8       0.85      0.75      0.80       800
#            9       0.94      0.96      0.95       800
#
#     accuracy                           0.80      8000
#    macro avg       0.81      0.80      0.80      8000
# weighted avg       0.81      0.80      0.80      8000
